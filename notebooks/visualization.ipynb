# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2
from sqlalchemy import create_engine

# %%
connect = 'postgresql+psycopg2://postgres:password@localhost:5432/yelp'
engine = create_engine(connect)
query = '''
        SELECT *
        FROM model_data_regression
        ;
        '''
df = pd.read_sql(query, con=engine)
data = df.copy()

# %%
pd.set_option('display.max_columns', 500)
pd.set_option("max_rows", 10000)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
print(data.info())
data.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4936284 entries, 0 to 4936283
# Data columns (total 21 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   review_id                            object
#  1   TARGET_review_upvotes_time_adjusted  float64
#  2   review_stars                         int64
#  3   review_stars_v_user_avg              float64
#  4   review_stars_v_restaurant_avg        float64
#  5   restaurant_latitude                  float64
#  6   restaurant_longitude                 float64
#  7   restaurant_overall_stars             float64
#  8   restaurant_review_count              int64
#  9   restaurant_checkin_count             int64
#  10  restaurant_is_open                   int64
#  11  restaurant_price                     int64
#  12  user_average_stars_given             float64
#  13  user_review_count                    int64
#  14  user_upvotes                         int64
# ...

# %%
df.describe()
# Out:
#        TARGET_review_upvotes_time_adjusted  review_stars  \
# count                        4936284.00000 4936284.00000
# mean                               0.00225       3.73308
# std                                0.01488       1.39249
# min                               -0.00191       1.00000
# 25%                                0.00000       3.00000
# 50%                                0.00000       4.00000
# 75%                                0.00158       5.00000
# max                                4.58231       5.00000
#
#        review_stars_v_user_avg  review_stars_v_restaurant_avg  \
# count            4936284.00000                  4936284.00000
# mean                  -0.01450                       -0.00139
# std                    1.18291                        1.26672
# min                   -3.93000                       -4.00000
# 25%                   -0.67000                       -1.00000
# 50%                    0.10000                        0.50000
# ...

# %%
df[df['user_days_active_at_review_time'] < 0]
# Out:
#                       review_id  TARGET_review_upvotes_time_adjusted  \
# 13704    JLgcGHwBIityO7OkZt4oeQ                              0.00075
# 86310    x8A3Z_PSGq7kGz8xmBE4Sw                              0.00000
# 137732   Q_3qXBG7-lD3W6w7QdOSUw                              0.00000
# 147951   yRinVhOzhsnNgMZ2SFYmhQ                              0.00000
# 156365   nyBD4xICee8v2JM8LwqTdw                              0.00000
# 172128   XhirrLgRmJ8xSgLJyoCcFQ                              0.00033
# 179808   BENpowgNv0XnspFxAjkiqg                              0.00000
# 220908   Y4vPH1tmSHH4pRkuNZPnTw                              0.00000
# 221326   S_q20mvuF-cNcLWxMnZMhQ                              0.00000
# 256243   cbEYOqpokDQ8Lcwjpqi7Pg                              0.00000
# 281603   g1-Q9JPXE-53FTxRJZ2_8Q                              0.00000
# 282122   X5_Fx1A8v99tcQtjW3_YsQ                              0.00000
# 288294   jC-eM0DRa1DYo7Z1qnXLOg                              0.00000
# ...

# %%
df['review_id'].value_counts().head(10)
# Out:
# 8ChcpU5OmG9AEdEvF4h1gQ    6
# IjkmtKj-BZG85qwAXrwxow    6
# e4r1ngmoJCRgKORKGMWnMA    6
# 0L4XmP9iu_3ieOEwWU1A3w    6
# ejyIX1_z72iHPQiZoBD9oA    6
# B505RP25rHlU_YIojsPj7w    6
# DeCPCI83TlSMg9AleQ0OBA    6
# lAmKSeK4knsRNzA8U8jJmg    6
# CtY1EytuIYTkyHhzD4h5OQ    6
# YdkgIWEKlXZ3EujSniG0SA    6
# Name: review_id, dtype: int64

# %%
df[df['review_id'] == '8ChcpU5OmG9AEdEvF4h1gQ']
# Out:
#                       review_id  TARGET_review_upvotes_time_adjusted  \
# 165264   8ChcpU5OmG9AEdEvF4h1gQ                              0.01610
# 2217036  8ChcpU5OmG9AEdEvF4h1gQ                              0.01610
# 2556956  8ChcpU5OmG9AEdEvF4h1gQ                              0.01610
# 4917294  8ChcpU5OmG9AEdEvF4h1gQ                              0.01610
# 4930919  8ChcpU5OmG9AEdEvF4h1gQ                              0.01610
# 4934686  8ChcpU5OmG9AEdEvF4h1gQ                              0.01610
#
#          review_stars  review_stars_v_user_avg  review_stars_v_restaurant_avg  \
# 165264              5                  0.96000                        0.50000
# 2217036             5                  0.96000                        0.50000
# 2556956             5                  0.96000                        0.50000
# 4917294             5                  0.96000                        0.50000
# 4930919             5                  0.96000                        0.50000
# ...
