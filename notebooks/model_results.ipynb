# %%
import pprint
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)
pd.set_option('display.width', 100)
pd.set_option("display.precision", 5)
plt.style.use('fivethirtyeight')
plt.rcParams.update({'font.size': 16, 'font.family': 'sans'})
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
filepath = '../models/model_info.csv'
model_results = pd.read_csv(filepath).copy()

# %%
model_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3041 entries, 0 to 3040
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   record_id                      3040 non-null   object
#  1   record_type                    3040 non-null   object
#  2   CV_fit_time                    3040 non-null   float64
#  3   CV_score_time                  3040 non-null   float64
#  4   refit_time                     2788 non-null   float64
#  5   CV_accuracy                    3040 non-null   float64
#  6   CV_balanced_accuracy           3040 non-null   float64
#  7   CV_F1_score                    3040 non-null   float64
#  8   CV_precision                   3040 non-null   float64
#  9   CV_recall                      3040 non-null   float64
#  10  CV_roc_auc                     3040 non-null   float64
#  11  CV_R2_score                    0 non-null      float64
#  12  CV_mse                         0 non-null      float64
#  13  CV_rmse                        0 non-null      float64
#  14  CV_mae                         0 non-null      float64
#  15  Test_accuracy                  2788 non-null   float64
#  16  Test_balanced_accuracy         2788 non-null   float64
#  17  Test_f1_score                  2788 non-null   float64
#  18  Test_precision                 2788 non-null   float64
#  19  Test_recall                    2788 non-null   float64
#  20  Test_hamming_loss              2788 non-null   float64
#  21  Test_jaccard_score             2788 non-null   float64
#  22  Test_log_loss                  2788 non-null   float64
#  23  Test_classification_report     2788 non-null   object
#  24  Test_false_negatives           2788 non-null   float64
#  25  Test_false_positives           2788 non-null   float64
#  26  Test_true_negatives            2788 non-null   float64
#  27  Test_true_positives            2788 non-null   float64
#  28  Test_confusion_matrix          2788 non-null   object
#  29  Test_r2_score                  0 non-null      float64
#  30  Test_mse                       0 non-null      float64
#  31  Test_rmse                      0 non-null      float64
#  32  Test_mae                       0 non-null      float64
#  33  Test_explained_variance_score  0 non-null      float64
#  34  data                           3040 non-null   object
#  35  goal                           3040 non-null   object
#  36  model_type                     3040 non-null   object
#  37  question                       3040 non-null   object
#  38  record_count                   3040 non-null   float64
#  39  target                         3040 non-null   object
#  40  scalar                         3040 non-null   object
#  41  balancer                       3040 non-null   object
#  42  hyperparameters                3040 non-null   object
#  43  features                       3040 non-null   object
#  44  full_runtime_minutes           2 non-null      float64
# dtypes: float64(32), object(13)
# memory usage: 1.0+ MB

# %%
show_results = model_results.query("record_type == 'test' & target == 'T2_CLS_ufc_>0'")

# %%
show_results = show_results.loc[:, ['record_id', 'data', 'model_type', 'Test_accuracy',
                 'Test_balanced_accuracy', 'Test_f1_score',
                 'Test_precision', 'Test_recall', 'Test_hamming_loss',
                 'Test_jaccard_score', 'Test_log_loss',
                 'hyperparameters']]

# %%
show_results = show_results.sort_values(by=['data', 'Test_accuracy'],
                                        ascending=False, ignore_index=True).drop_duplicates(ignore_index=True,
                                                                                           subset='record_id')
show_results
# Out:
#      record_id      data  model_type  Test_accuracy  Test_balanced_accuracy  Test_f1_score  \
# 0   mDrY3it80D      text  Forest Cls         0.5800                 0.57906        0.57914
# 1   CGagm8pxSz      text     Log Reg         0.5795                 0.57761        0.57754
# 2   N8y1RUyA6Y      text     XGB Cls         0.5730                 0.57144        0.57098
# 3   u3ilbEnNJ9      text     Log Reg         0.5655                 0.56399        0.56360
# 4   lzMwQGcsL9      text     HGB Cls         0.5615                 0.55992        0.56052
# 5   f1529Q2N3x      text     Log Reg         0.5610                 0.55753        0.55854
# 6   CY4Ab4y8hT      text  Forest Cls         0.5500                 0.50000        0.52308
# 7   QplKozhffy      text     Log Reg         0.5500                 0.54720        0.54672
# 8   hmhj7EY39X  non_text     XGB Cls         0.7130                 0.71274        0.71293
# 9   Fc3xOG2zYk  non_text  Forest Cls         0.7055                 0.70466        0.70539
# 10  fQSG7TaLZX  non_text     Log Reg         0.7000                 0.70018        0.70006
# 11  kniLtmS3C5  non_text     HGB Cls         0.7000                 0.69865        0.69947
# 12  AWCnNFH5Na      both     Log Reg         0.6445                 0.64347        0.64389
# 13  XyKjgDtZCm      both  Forest Cls         0.6440                 0.64271        0.64337
# 14  8aTyCyS4rw      both     HGB Cls         0.6430                 0.64182        0.64220
# 15  CpH7SOvU7o      both     XGB Cls         0.6290                 0.62680        0.62733
#
#     Test_precision  Test_recall  Test_hamming_loss  Test_jaccard_score  Test_log_loss  \
# 0          0.57978       0.5800             0.4200             0.40800        0.95742
# 1          0.57917       0.5795             0.4205             0.40688        0.98442
# 2          0.57284       0.5730             0.4270             0.40039        0.98316
# 3          0.56519       0.5655             0.4345             0.39316        1.00467
# 4          0.56080       0.5615             0.4385             0.38996        1.03528
# 5          0.55948       0.5610             0.4390             0.38881        1.04893
# 6          0.52000       0.5500             0.4500             0.37273        9.05846
# 7          0.54887       0.5500             0.4500             0.37762        1.08071
# 8          0.71298       0.7130             0.2870             0.55397        0.53677
# 9          0.70536       0.7055             0.2945             0.54506        0.54031
# 10         0.70044       0.7000             0.3000             0.53855        0.55605
# 11         0.70004       0.7000             0.3000             0.53816        0.54096
# 12         0.64447       0.6445             0.3555             0.47513        0.83147
# 13         0.64382       0.6440             0.3560             0.47462        0.81003
# 14         0.64307       0.6430             0.3570             0.47337        0.90302
# 15         0.62909       0.6290             0.3710             0.45781        0.94918
#
#                                       hyperparameters
# 0   {'random_state': 7, 'n_jobs': -1, 'n_estimator...
# 1   {'tol': 0.0001, 'solver': 'saga', 'random_stat...
# 2   {'subsample': 0.8, 'reg_lambda': 0.75, 'random...
# 3   {'tol': 0.0001, 'solver': 'lbfgs', 'random_sta...
# 4   {'random_state': 7, 'min_samples_leaf': 20, 'm...
# 5   {'tol': 0.0001, 'solver': 'saga', 'random_stat...
# 6   {'random_state': 7, 'n_estimators': 10, 'min_s...
# 7   {'tol': 0.0001, 'solver': 'lbfgs', 'random_sta...
# 8   {'subsample': 0.8, 'reg_lambda': 0.75, 'random...
# 9   {'random_state': 7, 'n_jobs': -1, 'n_estimator...
# 10  {'tol': 0.0001, 'solver': 'lbfgs', 'random_sta...
# 11  {'random_state': 7, 'min_samples_leaf': 20, 'm...
# 12  {'tol': 0.0001, 'solver': 'saga', 'random_stat...
# 13  {'random_state': 7, 'n_jobs': -1, 'n_estimator...
# 14  {'random_state': 7, 'min_samples_leaf': 20, 'm...
# 15  {'subsample': 0.8, 'reg_lambda': 0.75, 'random...

# %%
show_results = show_results[show_results['model_type'] == 'Forest Cls']
hyper_dict = show_results.loc[0:, ['hyperparameters']].to_dict()
for k, v in hyper_dict['hyperparameters'].items():
    print (f'Index: {k}')
    pprint.pprint(v)
    print()
# Out:
# Index: 0
# ("{'random_state': 7, 'n_jobs': -1, 'n_estimators': 50, 'min_samples_split': "
#  "2, 'min_samples_leaf': 5, 'max_samples': None, 'max_leaf_nodes': 100, "
#  "'max_features': 20, 'max_depth': None, 'criterion': 'gini', 'class_weight': "
#  'None}')
#
# Index: 6
# ("{'random_state': 7, 'n_estimators': 10, 'min_samples_split': 10, "
#  "'min_samples_leaf': 5, 'max_samples': None, 'max_leaf_nodes': 10, "
#  "'max_features': 10, 'max_depth': None, 'criterion': 'gini', 'class_weight': "
#  'None}')
#
# Index: 9
# ("{'random_state': 7, 'n_jobs': -1, 'n_estimators': 100, 'min_samples_split': "
#  "2, 'min_samples_leaf': 1, 'max_samples': None, 'max_leaf_nodes': None, "
#  "'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini', "
#  "'class_weight': None}")
#
# Index: 13
# ("{'random_state': 7, 'n_jobs': -1, 'n_estimators': 50, 'min_samples_split': "
#  "2, 'min_samples_leaf': 5, 'max_samples': None, 'max_leaf_nodes': 100, "
#  "'max_features': 20, 'max_depth': None, 'criterion': 'gini', 'class_weight': "
#  'None}')
