# %% [markdown]
# # Combined Text Data EDA Prep

# %% [markdown]
# This notebook includes:
# * Converting RDS table to CSV
# * Converting features to smaller datatypes.

# %% [markdown]
# ### Imports and Global Settings

# %%
import tempfile
import numpy as np
import pandas as pd
# Connecting to Postgres RDS on AWS
from sqlalchemy import create_engine
from sqlalchemy.dialects import postgresql

pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 200)

# %% [markdown]
# ### Import and Convert Data

# %%
db_endpoint = None
db_name = "yelp_2021_db"
db_password = None

# %%
engine = create_engine(f"postgresql+psycopg2://postgres:{db_password}@{db_endpoint}/{db_name}")

# %%
train_query = "SELECT * FROM text_combined_train"
test_query = "SELECT * FROM text_combined_test"

# %%
datatypes = {'target_reg': 'int16',
 'review_stars': 'int16',
 'NB_prob': 'float32',
 'svm_pred': 'float32',
 'grade_level': 'float32',
 'polarity': 'float32',
 'subjectivity': 'float32',
 'word_cnt': 'int16',
 'character_cnt': 'int16',
 'num_cnt': 'int16',
 'uppercase_cnt': 'int16',
 '#@_cnt': 'int16',
 'sentence_cnt': 'int16',
 'lexicon_cnt': 'int16',
 'syllable_cnt': 'int16',
 'avg_word_len': 'float32',
 'token_cnt': 'int16',
 'stopword_cnt': 'int16',
 'stopword_pct': 'float32',
 'ent_cnt': 'int16',
 'ent_pct': 'float32',
 'pos_adj_pct': 'float32',
 'pos_adj_cnt': 'int16',
 'pos_adp_pct': 'float32',
 'pos_adp_cnt': 'int16',
 'pos_adv_pct': 'float32',
 'pos_adv_cnt': 'int16',
 'pos_aux_pct': 'float32',
 'pos_aux_cnt': 'int16',
 'pos_conj_pct': 'float32',
 'pos_conj_cnt': 'int16',
 'pos_det_pct': 'float32',
 'pos_det_cnt': 'int16',
 'pos_intj_pct': 'float32',
 'pos_intj_cnt': 'int16',
 'pos_noun_pct': 'float32',
 'pos_noun_cnt': 'int16',
 'pos_num_pct': 'float32',
 'pos_num_cnt': 'int16',
 'pos_part_pct': 'float32',
 'pos_part_cnt': 'int16',
 'pos_pron_pct': 'float32',
 'pos_pron_cnt': 'int16',
 'pos_propn_pct': 'float32',
 'pos_propn_cnt': 'int16',
 'pos_punct_pct': 'float32',
 'pos_punct_cnt': 'int16',
 'pos_sconj_pct': 'float32',
 'pos_sconj_cnt': 'int16',
 'pos_sym_pct': 'float32',
 'pos_sym_cnt': 'int16',
 'pos_verb_pct': 'float32',
 'pos_verb_cnt': 'int16',
 'pos_x_pct': 'float32',
 'pos_x_cnt': 'int16',
 'dep_root_pct': 'float32',
 'dep_root_cnt': 'int16',
 'dep_acl_pct': 'float32',
 'dep_acl_cnt': 'int16',
 'dep_acomp_pct': 'float32',
 'dep_acomp_cnt': 'int16',
 'dep_advcl_pct': 'float32',
 'dep_advcl_cnt': 'int16',
 'dep_advmod_pct': 'float32',
 'dep_advmod_cnt': 'int16',
 'dep_agent_pct': 'float32',
 'dep_agent_cnt': 'int16',
 'dep_amod_pct': 'float32',
 'dep_amod_cnt': 'int16',
 'dep_appos_pct': 'float32',
 'dep_appos_cnt': 'int16',
 'dep_attr_pct': 'float32',
 'dep_attr_cnt': 'int16',
 'dep_aux_pct': 'float32',
 'dep_aux_cnt': 'int16',
 'dep_auxpass_pct': 'float32',
 'dep_auxpass_cnt': 'int16',
 'dep_case_pct': 'float32',
 'dep_case_cnt': 'int16',
 'dep_cc_pct': 'float32',
 'dep_cc_cnt': 'int16',
 'dep_ccomp_pct': 'float32',
 'dep_ccomp_cnt': 'int16',
 'dep_compound_pct': 'float32',
 'dep_compound_cnt': 'int16',
 'dep_conj_pct': 'float32',
 'dep_conj_cnt': 'int16',
 'dep_csubj_pct': 'float32',
 'dep_csubj_cnt': 'int16',
 'dep_csubjpass_pct': 'float32',
 'dep_csubjpass_cnt': 'int16',
 'dep_dative_pct': 'float32',
 'dep_dative_cnt': 'int16',
 'dep_dep_pct': 'float32',
 'dep_dep_cnt': 'int16',
 'dep_det_pct': 'float32',
 'dep_det_cnt': 'int16',
 'dep_dobj_pct': 'float32',
 'dep_dobj_cnt': 'int16',
 'dep_expl_pct': 'float32',
 'dep_expl_cnt': 'int16',
 'dep_intj_pct': 'float32',
 'dep_intj_cnt': 'int16',
 'dep_mark_pct': 'float32',
 'dep_mark_cnt': 'int16',
 'dep_meta_pct': 'float32',
 'dep_meta_cnt': 'int16',
 'dep_neg_pct': 'float32',
 'dep_neg_cnt': 'int16',
 'dep_nmod_pct': 'float32',
 'dep_nmod_cnt': 'int16',
 'dep_npadvmod_pct': 'float32',
 'dep_npadvmod_cnt': 'int16',
 'dep_nsubj_pct': 'float32',
 'dep_nsubj_cnt': 'int16',
 'dep_nsubjpass_pct': 'float32',
 'dep_nsubjpass_cnt': 'int16',
 'dep_nummod_pct': 'float32',
 'dep_nummod_cnt': 'int16',
 'dep_oprd_pct': 'float32',
 'dep_oprd_cnt': 'int16',
 'dep_parataxis_pct': 'float32',
 'dep_parataxis_cnt': 'int16',
 'dep_pcomp_pct': 'float32',
 'dep_pcomp_cnt': 'int16',
 'dep_pobj_pct': 'float32',
 'dep_pobj_cnt': 'int16',
 'dep_poss_pct': 'float32',
 'dep_poss_cnt': 'int16',
 'dep_preconj_pct': 'float32',
 'dep_preconj_cnt': 'int16',
 'dep_predet_pct': 'float32',
 'dep_predet_cnt': 'int16',
 'dep_prep_pct': 'float32',
 'dep_prep_cnt': 'int16',
 'dep_prt_pct': 'float32',
 'dep_prt_cnt': 'int16',
 'dep_punct_pct': 'float32',
 'dep_punct_cnt': 'int16',
 'dep_quantmod_pct': 'float32',
 'dep_quantmod_cnt': 'int16',
 'dep_relcl_pct': 'float32',
 'dep_relcl_cnt': 'int16',
 'dep_xcomp_pct': 'float32',
 'dep_xcomp_cnt': 'int16',
 'ent_cardinal_pct': 'float32',
 'ent_cardinal_cnt': 'int16',
 'ent_date_pct': 'float32',
 'ent_date_cnt': 'int16',
 'ent_event_pct': 'float32',
 'ent_event_cnt': 'int16',
 'ent_fac_pct': 'float32',
 'ent_fac_cnt': 'int16',
 'ent_gpe_pct': 'float32',
 'ent_gpe_cnt': 'int16',
 'ent_language_pct': 'float32',
 'ent_language_cnt': 'int16',
 'ent_law_pct': 'float32',
 'ent_law_cnt': 'int16',
 'ent_loc_pct': 'float32',
 'ent_loc_cnt': 'int16',
 'ent_money_pct': 'float32',
 'ent_money_cnt': 'int16',
 'ent_norp_pct': 'float32',
 'ent_norp_cnt': 'int16',
 'ent_ordinal_pct': 'float32',
 'ent_ordinal_cnt': 'int16',
 'ent_org_pct': 'float32',
 'ent_org_cnt': 'int16',
 'ent_percent_pct': 'float32',
 'ent_percent_cnt': 'int16',
 'ent_person_pct': 'float32',
 'ent_person_cnt': 'int16',
 'ent_product_pct': 'float32',
 'ent_product_cnt': 'int16',
 'ent_quantity_pct': 'float32',
 'ent_quantity_cnt': 'int16',
 'ent_time_pct': 'float32',
 'ent_time_cnt': 'int16',
 'ent_work_of_art_pct': 'float32',
 'ent_work_of_art_cnt': 'int16'}

# %%
def read_sql_tmpfile(query, db_engine, datatype_dict):
    with tempfile.TemporaryFile() as tmpfile:
        copy_sql = "COPY ({query}) TO STDOUT WITH CSV {head}".format(
           query=query, head="HEADER"
        )
        conn = db_engine.raw_connection()
        cur = conn.cursor()
        cur.copy_expert(copy_sql, tmpfile)
        tmpfile.seek(0)
        df = pd.read_csv(tmpfile, dtype=datatype_dict)
        return df

# %%
train = read_sql_tmpfile(train_query, engine, datatypes)
train = train.replace({'target_clf': {'t': True, 'f': False}})

# %%
train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5523992 entries, 0 to 5523991
# Data columns (total 183 columns):
#  #    Column               Dtype
# ---   ------               -----
#  0    review_id            object
#  1    target_clf           bool
#  2    target_reg           int16
#  3    review_stars         int16
#  4    NB_prob              float32
#  5    svm_pred             float32
#  6    grade_level          float32
#  7    polarity             float32
#  8    subjectivity         float32
#  9    word_cnt             int16
#  10   character_cnt        int16
#  11   num_cnt              int16
#  12   uppercase_cnt        int16
#  13   #@_cnt               int16
#  14   sentence_cnt         int16
#  15   lexicon_cnt          int16
#  16   syllable_cnt         int16
#  17   avg_word_len         float32
#  18   token_cnt            int16
#  19   stopword_cnt         int16
#  20   stopword_pct         float32
#  21   ent_cnt              int16
#  22   ent_pct              float32
#  23   pos_adj_pct          float32
#  24   pos_adj_cnt          int16
#  25   pos_adp_pct          float32
#  26   pos_adp_cnt          int16
#  27   pos_adv_pct          float32
#  28   pos_adv_cnt          int16
#  29   pos_aux_pct          float32
#  30   pos_aux_cnt          int16
#  31   pos_conj_pct         float32
#  32   pos_conj_cnt         int16
#  33   pos_det_pct          float32
#  34   pos_det_cnt          int16
#  35   pos_intj_pct         float32
#  36   pos_intj_cnt         int16
#  37   pos_noun_pct         float32
#  38   pos_noun_cnt         int16
#  39   pos_num_pct          float32
#  40   pos_num_cnt          int16
#  41   pos_part_pct         float32
#  42   pos_part_cnt         int16
#  43   pos_pron_pct         float32
#  44   pos_pron_cnt         int16
#  45   pos_propn_pct        float32
#  46   pos_propn_cnt        int16
#  47   pos_punct_pct        float32
#  48   pos_punct_cnt        int16
#  49   pos_sconj_pct        float32
#  50   pos_sconj_cnt        int16
#  51   pos_sym_pct          float32
#  52   pos_sym_cnt          int16
#  53   pos_verb_pct         float32
#  54   pos_verb_cnt         int16
#  55   pos_x_pct            float32
#  56   pos_x_cnt            int16
#  57   dep_root_pct         float32
#  58   dep_root_cnt         int16
#  59   dep_acl_pct          float32
#  60   dep_acl_cnt          int16
#  61   dep_acomp_pct        float32
#  62   dep_acomp_cnt        int16
#  63   dep_advcl_pct        float32
#  64   dep_advcl_cnt        int16
#  65   dep_advmod_pct       float32
#  66   dep_advmod_cnt       int16
#  67   dep_agent_pct        float32
#  68   dep_agent_cnt        int16
#  69   dep_amod_pct         float32
#  70   dep_amod_cnt         int16
#  71   dep_appos_pct        float32
#  72   dep_appos_cnt        int16
#  73   dep_attr_pct         float32
#  74   dep_attr_cnt         int16
#  75   dep_aux_pct          float32
#  76   dep_aux_cnt          int16
#  77   dep_auxpass_pct      float32
#  78   dep_auxpass_cnt      int16
#  79   dep_case_pct         float32
#  80   dep_case_cnt         int16
#  81   dep_cc_pct           float32
#  82   dep_cc_cnt           int16
#  83   dep_ccomp_pct        float32
#  84   dep_ccomp_cnt        int16
#  85   dep_compound_pct     float32
#  86   dep_compound_cnt     int16
#  87   dep_conj_pct         float32
#  88   dep_conj_cnt         int16
#  89   dep_csubj_pct        float32
#  90   dep_csubj_cnt        int16
#  91   dep_csubjpass_pct    float32
#  92   dep_csubjpass_cnt    int16
#  93   dep_dative_pct       float32
#  94   dep_dative_cnt       int16
#  95   dep_dep_pct          float32
#  96   dep_dep_cnt          int16
#  97   dep_det_pct          float32
#  98   dep_det_cnt          int16
#  99   dep_dobj_pct         float32
#  100  dep_dobj_cnt         int16
#  101  dep_expl_pct         float32
#  102  dep_expl_cnt         int16
#  103  dep_intj_pct         float32
#  104  dep_intj_cnt         int16
#  105  dep_mark_pct         float32
#  106  dep_mark_cnt         int16
#  107  dep_meta_pct         float32
#  108  dep_meta_cnt         int16
#  109  dep_neg_pct          float32
#  110  dep_neg_cnt          int16
#  111  dep_nmod_pct         float32
#  112  dep_nmod_cnt         int16
#  113  dep_npadvmod_pct     float32
#  114  dep_npadvmod_cnt     int16
#  115  dep_nsubj_pct        float32
#  116  dep_nsubj_cnt        int16
#  117  dep_nsubjpass_pct    float32
#  118  dep_nsubjpass_cnt    int16
#  119  dep_nummod_pct       float32
#  120  dep_nummod_cnt       int16
#  121  dep_oprd_pct         float32
#  122  dep_oprd_cnt         int16
#  123  dep_parataxis_pct    float32
#  124  dep_parataxis_cnt    int16
#  125  dep_pcomp_pct        float32
#  126  dep_pcomp_cnt        int16
#  127  dep_pobj_pct         float32
#  128  dep_pobj_cnt         int16
#  129  dep_poss_pct         float32
#  130  dep_poss_cnt         int16
#  131  dep_preconj_pct      float32
#  132  dep_preconj_cnt      int16
#  133  dep_predet_pct       float32
#  134  dep_predet_cnt       int16
#  135  dep_prep_pct         float32
#  136  dep_prep_cnt         int16
#  137  dep_prt_pct          float32
#  138  dep_prt_cnt          int16
#  139  dep_punct_pct        float32
#  140  dep_punct_cnt        int16
#  141  dep_quantmod_pct     float32
#  142  dep_quantmod_cnt     int16
#  143  dep_relcl_pct        float32
#  144  dep_relcl_cnt        int16
#  145  dep_xcomp_pct        float32
#  146  dep_xcomp_cnt        int16
#  147  ent_cardinal_pct     float32
#  148  ent_cardinal_cnt     int16
#  149  ent_date_pct         float32
#  150  ent_date_cnt         int16
#  151  ent_event_pct        float32
#  152  ent_event_cnt        int16
#  153  ent_fac_pct          float32
#  154  ent_fac_cnt          int16
#  155  ent_gpe_pct          float32
#  156  ent_gpe_cnt          int16
#  157  ent_language_pct     float32
#  158  ent_language_cnt     int16
#  159  ent_law_pct          float32
#  160  ent_law_cnt          int16
#  161  ent_loc_pct          float32
#  162  ent_loc_cnt          int16
#  163  ent_money_pct        float32
#  164  ent_money_cnt        int16
#  165  ent_norp_pct         float32
#  166  ent_norp_cnt         int16
#  167  ent_ordinal_pct      float32
#  168  ent_ordinal_cnt      int16
#  169  ent_org_pct          float32
#  170  ent_org_cnt          int16
#  171  ent_percent_pct      float32
#  172  ent_percent_cnt      int16
#  173  ent_person_pct       float32
#  174  ent_person_cnt       int16
#  175  ent_product_pct      float32
#  176  ent_product_cnt      int16
#  177  ent_quantity_pct     float32
#  178  ent_quantity_cnt     int16
#  179  ent_time_pct         float32
#  180  ent_time_cnt         int16
#  181  ent_work_of_art_pct  float32
#  182  ent_work_of_art_cnt  int16
# dtypes: bool(1), float32(88), int16(93), object(1)
# memory usage: 2.8+ GB

# %%
train.memory_usage(deep=True)
# Out:
# Index                        128
# review_id              436395368
# target_clf               5523992
# target_reg              11047984
# review_stars            11047984
# NB_prob                 22095968
# svm_pred                22095968
# grade_level             22095968
# polarity                22095968
# subjectivity            22095968
# word_cnt                11047984
# character_cnt           11047984
# num_cnt                 11047984
# uppercase_cnt           11047984
# #@_cnt                  11047984
# sentence_cnt            11047984
# lexicon_cnt             11047984
# syllable_cnt            11047984
# avg_word_len            22095968
# token_cnt               11047984
# stopword_cnt            11047984
# stopword_pct            22095968
# ent_cnt                 11047984
# ent_pct                 22095968
# pos_adj_pct             22095968
# pos_adj_cnt             11047984
# pos_adp_pct             22095968
# pos_adp_cnt             11047984
# pos_adv_pct             22095968
# pos_adv_cnt             11047984
# pos_aux_pct             22095968
# pos_aux_cnt             11047984
# pos_conj_pct            22095968
# pos_conj_cnt            11047984
# pos_det_pct             22095968
# pos_det_cnt             11047984
# pos_intj_pct            22095968
# pos_intj_cnt            11047984
# pos_noun_pct            22095968
# pos_noun_cnt            11047984
# pos_num_pct             22095968
# pos_num_cnt             11047984
# pos_part_pct            22095968
# pos_part_cnt            11047984
# pos_pron_pct            22095968
# pos_pron_cnt            11047984
# pos_propn_pct           22095968
# pos_propn_cnt           11047984
# pos_punct_pct           22095968
# pos_punct_cnt           11047984
# pos_sconj_pct           22095968
# pos_sconj_cnt           11047984
# pos_sym_pct             22095968
# pos_sym_cnt             11047984
# pos_verb_pct            22095968
# pos_verb_cnt            11047984
# pos_x_pct               22095968
# pos_x_cnt               11047984
# dep_root_pct            22095968
# dep_root_cnt            11047984
# dep_acl_pct             22095968
# dep_acl_cnt             11047984
# dep_acomp_pct           22095968
# dep_acomp_cnt           11047984
# dep_advcl_pct           22095968
# dep_advcl_cnt           11047984
# dep_advmod_pct          22095968
# dep_advmod_cnt          11047984
# dep_agent_pct           22095968
# dep_agent_cnt           11047984
# dep_amod_pct            22095968
# dep_amod_cnt            11047984
# dep_appos_pct           22095968
# dep_appos_cnt           11047984
# dep_attr_pct            22095968
# dep_attr_cnt            11047984
# dep_aux_pct             22095968
# dep_aux_cnt             11047984
# dep_auxpass_pct         22095968
# dep_auxpass_cnt         11047984
# dep_case_pct            22095968
# dep_case_cnt            11047984
# dep_cc_pct              22095968
# dep_cc_cnt              11047984
# dep_ccomp_pct           22095968
# dep_ccomp_cnt           11047984
# dep_compound_pct        22095968
# dep_compound_cnt        11047984
# dep_conj_pct            22095968
# dep_conj_cnt            11047984
# dep_csubj_pct           22095968
# dep_csubj_cnt           11047984
# dep_csubjpass_pct       22095968
# dep_csubjpass_cnt       11047984
# dep_dative_pct          22095968
# dep_dative_cnt          11047984
# dep_dep_pct             22095968
# dep_dep_cnt             11047984
# dep_det_pct             22095968
# dep_det_cnt             11047984
# dep_dobj_pct            22095968
# dep_dobj_cnt            11047984
# dep_expl_pct            22095968
# dep_expl_cnt            11047984
# dep_intj_pct            22095968
# dep_intj_cnt            11047984
# dep_mark_pct            22095968
# dep_mark_cnt            11047984
# dep_meta_pct            22095968
# dep_meta_cnt            11047984
# dep_neg_pct             22095968
# dep_neg_cnt             11047984
# dep_nmod_pct            22095968
# dep_nmod_cnt            11047984
# dep_npadvmod_pct        22095968
# dep_npadvmod_cnt        11047984
# dep_nsubj_pct           22095968
# dep_nsubj_cnt           11047984
# dep_nsubjpass_pct       22095968
# dep_nsubjpass_cnt       11047984
# dep_nummod_pct          22095968
# dep_nummod_cnt          11047984
# dep_oprd_pct            22095968
# dep_oprd_cnt            11047984
# dep_parataxis_pct       22095968
# dep_parataxis_cnt       11047984
# dep_pcomp_pct           22095968
# dep_pcomp_cnt           11047984
# dep_pobj_pct            22095968
# dep_pobj_cnt            11047984
# dep_poss_pct            22095968
# dep_poss_cnt            11047984
# dep_preconj_pct         22095968
# dep_preconj_cnt         11047984
# dep_predet_pct          22095968
# dep_predet_cnt          11047984
# dep_prep_pct            22095968
# dep_prep_cnt            11047984
# dep_prt_pct             22095968
# dep_prt_cnt             11047984
# dep_punct_pct           22095968
# dep_punct_cnt           11047984
# dep_quantmod_pct        22095968
# dep_quantmod_cnt        11047984
# dep_relcl_pct           22095968
# dep_relcl_cnt           11047984
# dep_xcomp_pct           22095968
# dep_xcomp_cnt           11047984
# ent_cardinal_pct        22095968
# ent_cardinal_cnt        11047984
# ent_date_pct            22095968
# ent_date_cnt            11047984
# ent_event_pct           22095968
# ent_event_cnt           11047984
# ent_fac_pct             22095968
# ent_fac_cnt             11047984
# ent_gpe_pct             22095968
# ent_gpe_cnt             11047984
# ent_language_pct        22095968
# ent_language_cnt        11047984
# ent_law_pct             22095968
# ent_law_cnt             11047984
# ent_loc_pct             22095968
# ent_loc_cnt             11047984
# ent_money_pct           22095968
# ent_money_cnt           11047984
# ent_norp_pct            22095968
# ent_norp_cnt            11047984
# ent_ordinal_pct         22095968
# ent_ordinal_cnt         11047984
# ent_org_pct             22095968
# ent_org_cnt             11047984
# ent_percent_pct         22095968
# ent_percent_cnt         11047984
# ent_person_pct          22095968
# ent_person_cnt          11047984
# ent_product_pct         22095968
# ent_product_cnt         11047984
# ent_quantity_pct        22095968
# ent_quantity_cnt        11047984
# ent_time_pct            22095968
# ent_time_cnt            11047984
# ent_work_of_art_pct     22095968
# ent_work_of_art_cnt     11047984
# dtype: int64

# %%
test = read_sql_tmpfile(test_query, engine, datatypes)
test = test.replace({'target_clf': {'t': True, 'f': False}})

# %%
test.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382379 entries, 0 to 1382378
# Data columns (total 183 columns):
#  #    Column               Dtype
# ---   ------               -----
#  0    review_id            object
#  1    target_clf           bool
#  2    target_reg           int16
#  3    review_stars         int16
#  4    NB_prob              float32
#  5    svm_pred             float32
#  6    grade_level          float32
#  7    polarity             float32
#  8    subjectivity         float32
#  9    word_cnt             int16
#  10   character_cnt        int16
#  11   num_cnt              int16
#  12   uppercase_cnt        int16
#  13   #@_cnt               int16
#  14   sentence_cnt         int16
#  15   lexicon_cnt          int16
#  16   syllable_cnt         int16
#  17   avg_word_len         float32
#  18   token_cnt            int16
#  19   stopword_cnt         int16
#  20   stopword_pct         float32
#  21   ent_cnt              int16
#  22   ent_pct              float32
#  23   pos_adj_pct          float32
#  24   pos_adj_cnt          int16
#  25   pos_adp_pct          float32
#  26   pos_adp_cnt          int16
#  27   pos_adv_pct          float32
#  28   pos_adv_cnt          int16
#  29   pos_aux_pct          float32
#  30   pos_aux_cnt          int16
#  31   pos_conj_pct         float32
#  32   pos_conj_cnt         int16
#  33   pos_det_pct          float32
#  34   pos_det_cnt          int16
#  35   pos_intj_pct         float32
#  36   pos_intj_cnt         int16
#  37   pos_noun_pct         float32
#  38   pos_noun_cnt         int16
#  39   pos_num_pct          float32
#  40   pos_num_cnt          int16
#  41   pos_part_pct         float32
#  42   pos_part_cnt         int16
#  43   pos_pron_pct         float32
#  44   pos_pron_cnt         int16
#  45   pos_propn_pct        float32
#  46   pos_propn_cnt        int16
#  47   pos_punct_pct        float32
#  48   pos_punct_cnt        int16
#  49   pos_sconj_pct        float32
#  50   pos_sconj_cnt        int16
#  51   pos_sym_pct          float32
#  52   pos_sym_cnt          int16
#  53   pos_verb_pct         float32
#  54   pos_verb_cnt         int16
#  55   pos_x_pct            float32
#  56   pos_x_cnt            int16
#  57   dep_root_pct         float32
#  58   dep_root_cnt         int16
#  59   dep_acl_pct          float32
#  60   dep_acl_cnt          int16
#  61   dep_acomp_pct        float32
#  62   dep_acomp_cnt        int16
#  63   dep_advcl_pct        float32
#  64   dep_advcl_cnt        int16
#  65   dep_advmod_pct       float32
#  66   dep_advmod_cnt       int16
#  67   dep_agent_pct        float32
#  68   dep_agent_cnt        int16
#  69   dep_amod_pct         float32
#  70   dep_amod_cnt         int16
#  71   dep_appos_pct        float32
#  72   dep_appos_cnt        int16
#  73   dep_attr_pct         float32
#  74   dep_attr_cnt         int16
#  75   dep_aux_pct          float32
#  76   dep_aux_cnt          int16
#  77   dep_auxpass_pct      float32
#  78   dep_auxpass_cnt      int16
#  79   dep_case_pct         float32
#  80   dep_case_cnt         int16
#  81   dep_cc_pct           float32
#  82   dep_cc_cnt           int16
#  83   dep_ccomp_pct        float32
#  84   dep_ccomp_cnt        int16
#  85   dep_compound_pct     float32
#  86   dep_compound_cnt     int16
#  87   dep_conj_pct         float32
#  88   dep_conj_cnt         int16
#  89   dep_csubj_pct        float32
#  90   dep_csubj_cnt        int16
#  91   dep_csubjpass_pct    float32
#  92   dep_csubjpass_cnt    int16
#  93   dep_dative_pct       float32
#  94   dep_dative_cnt       int16
#  95   dep_dep_pct          float32
#  96   dep_dep_cnt          int16
#  97   dep_det_pct          float32
#  98   dep_det_cnt          int16
#  99   dep_dobj_pct         float32
#  100  dep_dobj_cnt         int16
#  101  dep_expl_pct         float32
#  102  dep_expl_cnt         int16
#  103  dep_intj_pct         float32
#  104  dep_intj_cnt         int16
#  105  dep_mark_pct         float32
#  106  dep_mark_cnt         int16
#  107  dep_meta_pct         float32
#  108  dep_meta_cnt         int16
#  109  dep_neg_pct          float32
#  110  dep_neg_cnt          int16
#  111  dep_nmod_pct         float32
#  112  dep_nmod_cnt         int16
#  113  dep_npadvmod_pct     float32
#  114  dep_npadvmod_cnt     int16
#  115  dep_nsubj_pct        float32
#  116  dep_nsubj_cnt        int16
#  117  dep_nsubjpass_pct    float32
#  118  dep_nsubjpass_cnt    int16
#  119  dep_nummod_pct       float32
#  120  dep_nummod_cnt       int16
#  121  dep_oprd_pct         float32
#  122  dep_oprd_cnt         int16
#  123  dep_parataxis_pct    float32
#  124  dep_parataxis_cnt    int16
#  125  dep_pcomp_pct        float32
#  126  dep_pcomp_cnt        int16
#  127  dep_pobj_pct         float32
#  128  dep_pobj_cnt         int16
#  129  dep_poss_pct         float32
#  130  dep_poss_cnt         int16
#  131  dep_preconj_pct      float32
#  132  dep_preconj_cnt      int16
#  133  dep_predet_pct       float32
#  134  dep_predet_cnt       int16
#  135  dep_prep_pct         float32
#  136  dep_prep_cnt         int16
#  137  dep_prt_pct          float32
#  138  dep_prt_cnt          int16
#  139  dep_punct_pct        float32
#  140  dep_punct_cnt        int16
#  141  dep_quantmod_pct     float32
#  142  dep_quantmod_cnt     int16
#  143  dep_relcl_pct        float32
#  144  dep_relcl_cnt        int16
#  145  dep_xcomp_pct        float32
#  146  dep_xcomp_cnt        int16
#  147  ent_cardinal_pct     float32
#  148  ent_cardinal_cnt     int16
#  149  ent_date_pct         float32
#  150  ent_date_cnt         int16
#  151  ent_event_pct        float32
#  152  ent_event_cnt        int16
#  153  ent_fac_pct          float32
#  154  ent_fac_cnt          int16
#  155  ent_gpe_pct          float32
#  156  ent_gpe_cnt          int16
#  157  ent_language_pct     float32
#  158  ent_language_cnt     int16
#  159  ent_law_pct          float32
#  160  ent_law_cnt          int16
#  161  ent_loc_pct          float32
#  162  ent_loc_cnt          int16
#  163  ent_money_pct        float32
#  164  ent_money_cnt        int16
#  165  ent_norp_pct         float32
#  166  ent_norp_cnt         int16
#  167  ent_ordinal_pct      float32
#  168  ent_ordinal_cnt      int16
#  169  ent_org_pct          float32
#  170  ent_org_cnt          int16
#  171  ent_percent_pct      float32
#  172  ent_percent_cnt      int16
#  173  ent_person_pct       float32
#  174  ent_person_cnt       int16
#  175  ent_product_pct      float32
#  176  ent_product_cnt      int16
#  177  ent_quantity_pct     float32
#  178  ent_quantity_cnt     int16
#  179  ent_time_pct         float32
#  180  ent_time_cnt         int16
#  181  ent_work_of_art_pct  float32
#  182  ent_work_of_art_cnt  int16
# dtypes: bool(1), float32(88), int16(93), object(1)
# memory usage: 721.1+ MB

# %%
test.memory_usage(deep=True)
# Out:
# Index                        128
# review_id              109207941
# target_clf               1382379
# target_reg               2764758
# review_stars             2764758
# NB_prob                  5529516
# svm_pred                 5529516
# grade_level              5529516
# polarity                 5529516
# subjectivity             5529516
# word_cnt                 2764758
# character_cnt            2764758
# num_cnt                  2764758
# uppercase_cnt            2764758
# #@_cnt                   2764758
# sentence_cnt             2764758
# lexicon_cnt              2764758
# syllable_cnt             2764758
# avg_word_len             5529516
# token_cnt                2764758
# stopword_cnt             2764758
# stopword_pct             5529516
# ent_cnt                  2764758
# ent_pct                  5529516
# pos_adj_pct              5529516
# pos_adj_cnt              2764758
# pos_adp_pct              5529516
# pos_adp_cnt              2764758
# pos_adv_pct              5529516
# pos_adv_cnt              2764758
# pos_aux_pct              5529516
# pos_aux_cnt              2764758
# pos_conj_pct             5529516
# pos_conj_cnt             2764758
# pos_det_pct              5529516
# pos_det_cnt              2764758
# pos_intj_pct             5529516
# pos_intj_cnt             2764758
# pos_noun_pct             5529516
# pos_noun_cnt             2764758
# pos_num_pct              5529516
# pos_num_cnt              2764758
# pos_part_pct             5529516
# pos_part_cnt             2764758
# pos_pron_pct             5529516
# pos_pron_cnt             2764758
# pos_propn_pct            5529516
# pos_propn_cnt            2764758
# pos_punct_pct            5529516
# pos_punct_cnt            2764758
# pos_sconj_pct            5529516
# pos_sconj_cnt            2764758
# pos_sym_pct              5529516
# pos_sym_cnt              2764758
# pos_verb_pct             5529516
# pos_verb_cnt             2764758
# pos_x_pct                5529516
# pos_x_cnt                2764758
# dep_root_pct             5529516
# dep_root_cnt             2764758
# dep_acl_pct              5529516
# dep_acl_cnt              2764758
# dep_acomp_pct            5529516
# dep_acomp_cnt            2764758
# dep_advcl_pct            5529516
# dep_advcl_cnt            2764758
# dep_advmod_pct           5529516
# dep_advmod_cnt           2764758
# dep_agent_pct            5529516
# dep_agent_cnt            2764758
# dep_amod_pct             5529516
# dep_amod_cnt             2764758
# dep_appos_pct            5529516
# dep_appos_cnt            2764758
# dep_attr_pct             5529516
# dep_attr_cnt             2764758
# dep_aux_pct              5529516
# dep_aux_cnt              2764758
# dep_auxpass_pct          5529516
# dep_auxpass_cnt          2764758
# dep_case_pct             5529516
# dep_case_cnt             2764758
# dep_cc_pct               5529516
# dep_cc_cnt               2764758
# dep_ccomp_pct            5529516
# dep_ccomp_cnt            2764758
# dep_compound_pct         5529516
# dep_compound_cnt         2764758
# dep_conj_pct             5529516
# dep_conj_cnt             2764758
# dep_csubj_pct            5529516
# dep_csubj_cnt            2764758
# dep_csubjpass_pct        5529516
# dep_csubjpass_cnt        2764758
# dep_dative_pct           5529516
# dep_dative_cnt           2764758
# dep_dep_pct              5529516
# dep_dep_cnt              2764758
# dep_det_pct              5529516
# dep_det_cnt              2764758
# dep_dobj_pct             5529516
# dep_dobj_cnt             2764758
# dep_expl_pct             5529516
# dep_expl_cnt             2764758
# dep_intj_pct             5529516
# dep_intj_cnt             2764758
# dep_mark_pct             5529516
# dep_mark_cnt             2764758
# dep_meta_pct             5529516
# dep_meta_cnt             2764758
# dep_neg_pct              5529516
# dep_neg_cnt              2764758
# dep_nmod_pct             5529516
# dep_nmod_cnt             2764758
# dep_npadvmod_pct         5529516
# dep_npadvmod_cnt         2764758
# dep_nsubj_pct            5529516
# dep_nsubj_cnt            2764758
# dep_nsubjpass_pct        5529516
# dep_nsubjpass_cnt        2764758
# dep_nummod_pct           5529516
# dep_nummod_cnt           2764758
# dep_oprd_pct             5529516
# dep_oprd_cnt             2764758
# dep_parataxis_pct        5529516
# dep_parataxis_cnt        2764758
# dep_pcomp_pct            5529516
# dep_pcomp_cnt            2764758
# dep_pobj_pct             5529516
# dep_pobj_cnt             2764758
# dep_poss_pct             5529516
# dep_poss_cnt             2764758
# dep_preconj_pct          5529516
# dep_preconj_cnt          2764758
# dep_predet_pct           5529516
# dep_predet_cnt           2764758
# dep_prep_pct             5529516
# dep_prep_cnt             2764758
# dep_prt_pct              5529516
# dep_prt_cnt              2764758
# dep_punct_pct            5529516
# dep_punct_cnt            2764758
# dep_quantmod_pct         5529516
# dep_quantmod_cnt         2764758
# dep_relcl_pct            5529516
# dep_relcl_cnt            2764758
# dep_xcomp_pct            5529516
# dep_xcomp_cnt            2764758
# ent_cardinal_pct         5529516
# ent_cardinal_cnt         2764758
# ent_date_pct             5529516
# ent_date_cnt             2764758
# ent_event_pct            5529516
# ent_event_cnt            2764758
# ent_fac_pct              5529516
# ent_fac_cnt              2764758
# ent_gpe_pct              5529516
# ent_gpe_cnt              2764758
# ent_language_pct         5529516
# ent_language_cnt         2764758
# ent_law_pct              5529516
# ent_law_cnt              2764758
# ent_loc_pct              5529516
# ent_loc_cnt              2764758
# ent_money_pct            5529516
# ent_money_cnt            2764758
# ent_norp_pct             5529516
# ent_norp_cnt             2764758
# ent_ordinal_pct          5529516
# ent_ordinal_cnt          2764758
# ent_org_pct              5529516
# ent_org_cnt              2764758
# ent_percent_pct          5529516
# ent_percent_cnt          2764758
# ent_person_pct           5529516
# ent_person_cnt           2764758
# ent_product_pct          5529516
# ent_product_cnt          2764758
# ent_quantity_pct         5529516
# ent_quantity_cnt         2764758
# ent_time_pct             5529516
# ent_time_cnt             2764758
# ent_work_of_art_pct      5529516
# ent_work_of_art_cnt      2764758
# dtype: int64

# %% [markdown]
# ### To CSV

# %%
filepath_prefix = "/home/jeff/Documents/Data_Science_Projects/Yelp_Reviews/data/full_data/model_ready/"

# %%
train.to_csv(f"{filepath_prefix}train.csv", index=False)

# %%
test.to_csv(f"{filepath_prefix}test.csv", index=False)
