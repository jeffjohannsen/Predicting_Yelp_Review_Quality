# %% [markdown]
# # PyCaret AutoML

# %% [markdown]
# ## Imports and Global Settings

# %%
import numpy as np
import pandas as pd
from pycaret.classification import *

pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 200)

# %% [markdown]
# ## Loading Data

# %%
# EC2
filepath_prefix = "/home/ubuntu/"
# Local

# filepath_prefix = "/home/jeff/Documents/Data_Science_Projects/Yelp_Reviews/data/full_data/model_ready/"

# %%
train_records_to_load = 10000
test_records_to_load = 10000

# %%
datatypes = {'target_reg': 'int16',
 'review_stars': 'int16',
 'NB_prob': 'float32',
 'svm_pred': 'float32',
 'ft_prob': 'float32',
 'lda_t1': 'float32',
 'lda_t2': 'float32',
 'lda_t3': 'float32',
 'lda_t4': 'float32',
 'lda_t5': 'float32',
 'grade_level': 'float32',
 'polarity': 'float32',
 'subjectivity': 'float32',
 'word_cnt': 'int16',
 'character_cnt': 'int16',
 'num_cnt': 'int16',
 'uppercase_cnt': 'int16',
 '#@_cnt': 'int16',
 'sentence_cnt': 'int16',
 'lexicon_cnt': 'int16',
 'syllable_cnt': 'int16',
 'avg_word_len': 'float32',
 'token_cnt': 'int16',
 'stopword_cnt': 'int16',
 'stopword_pct': 'float32',
 'ent_cnt': 'int16',
 'ent_pct': 'float32',
 'pos_adj_pct': 'float32',
 'pos_adj_cnt': 'int16',
 'pos_adp_pct': 'float32',
 'pos_adp_cnt': 'int16',
 'pos_adv_pct': 'float32',
 'pos_adv_cnt': 'int16',
 'pos_aux_pct': 'float32',
 'pos_aux_cnt': 'int16',
 'pos_conj_pct': 'float32',
 'pos_conj_cnt': 'int16',
 'pos_det_pct': 'float32',
 'pos_det_cnt': 'int16',
 'pos_intj_pct': 'float32',
 'pos_intj_cnt': 'int16',
 'pos_noun_pct': 'float32',
 'pos_noun_cnt': 'int16',
 'pos_num_pct': 'float32',
 'pos_num_cnt': 'int16',
 'pos_part_pct': 'float32',
 'pos_part_cnt': 'int16',
 'pos_pron_pct': 'float32',
 'pos_pron_cnt': 'int16',
 'pos_propn_pct': 'float32',
 'pos_propn_cnt': 'int16',
 'pos_punct_pct': 'float32',
 'pos_punct_cnt': 'int16',
 'pos_sconj_pct': 'float32',
 'pos_sconj_cnt': 'int16',
 'pos_sym_pct': 'float32',
 'pos_sym_cnt': 'int16',
 'pos_verb_pct': 'float32',
 'pos_verb_cnt': 'int16',
 'pos_x_pct': 'float32',
 'pos_x_cnt': 'int16',
 'dep_root_pct': 'float32',
 'dep_root_cnt': 'int16',
 'dep_acl_pct': 'float32',
 'dep_acl_cnt': 'int16',
 'dep_acomp_pct': 'float32',
 'dep_acomp_cnt': 'int16',
 'dep_advcl_pct': 'float32',
 'dep_advcl_cnt': 'int16',
 'dep_advmod_pct': 'float32',
 'dep_advmod_cnt': 'int16',
 'dep_agent_pct': 'float32',
 'dep_agent_cnt': 'int16',
 'dep_amod_pct': 'float32',
 'dep_amod_cnt': 'int16',
 'dep_appos_pct': 'float32',
 'dep_appos_cnt': 'int16',
 'dep_attr_pct': 'float32',
 'dep_attr_cnt': 'int16',
 'dep_aux_pct': 'float32',
 'dep_aux_cnt': 'int16',
 'dep_auxpass_pct': 'float32',
 'dep_auxpass_cnt': 'int16',
 'dep_case_pct': 'float32',
 'dep_case_cnt': 'int16',
 'dep_cc_pct': 'float32',
 'dep_cc_cnt': 'int16',
 'dep_ccomp_pct': 'float32',
 'dep_ccomp_cnt': 'int16',
 'dep_compound_pct': 'float32',
 'dep_compound_cnt': 'int16',
 'dep_conj_pct': 'float32',
 'dep_conj_cnt': 'int16',
 'dep_csubj_pct': 'float32',
 'dep_csubj_cnt': 'int16',
 'dep_csubjpass_pct': 'float32',
 'dep_csubjpass_cnt': 'int16',
 'dep_dative_pct': 'float32',
 'dep_dative_cnt': 'int16',
 'dep_dep_pct': 'float32',
 'dep_dep_cnt': 'int16',
 'dep_det_pct': 'float32',
 'dep_det_cnt': 'int16',
 'dep_dobj_pct': 'float32',
 'dep_dobj_cnt': 'int16',
 'dep_expl_pct': 'float32',
 'dep_expl_cnt': 'int16',
 'dep_intj_pct': 'float32',
 'dep_intj_cnt': 'int16',
 'dep_mark_pct': 'float32',
 'dep_mark_cnt': 'int16',
 'dep_meta_pct': 'float32',
 'dep_meta_cnt': 'int16',
 'dep_neg_pct': 'float32',
 'dep_neg_cnt': 'int16',
 'dep_nmod_pct': 'float32',
 'dep_nmod_cnt': 'int16',
 'dep_npadvmod_pct': 'float32',
 'dep_npadvmod_cnt': 'int16',
 'dep_nsubj_pct': 'float32',
 'dep_nsubj_cnt': 'int16',
 'dep_nsubjpass_pct': 'float32',
 'dep_nsubjpass_cnt': 'int16',
 'dep_nummod_pct': 'float32',
 'dep_nummod_cnt': 'int16',
 'dep_oprd_pct': 'float32',
 'dep_oprd_cnt': 'int16',
 'dep_parataxis_pct': 'float32',
 'dep_parataxis_cnt': 'int16',
 'dep_pcomp_pct': 'float32',
 'dep_pcomp_cnt': 'int16',
 'dep_pobj_pct': 'float32',
 'dep_pobj_cnt': 'int16',
 'dep_poss_pct': 'float32',
 'dep_poss_cnt': 'int16',
 'dep_preconj_pct': 'float32',
 'dep_preconj_cnt': 'int16',
 'dep_predet_pct': 'float32',
 'dep_predet_cnt': 'int16',
 'dep_prep_pct': 'float32',
 'dep_prep_cnt': 'int16',
 'dep_prt_pct': 'float32',
 'dep_prt_cnt': 'int16',
 'dep_punct_pct': 'float32',
 'dep_punct_cnt': 'int16',
 'dep_quantmod_pct': 'float32',
 'dep_quantmod_cnt': 'int16',
 'dep_relcl_pct': 'float32',
 'dep_relcl_cnt': 'int16',
 'dep_xcomp_pct': 'float32',
 'dep_xcomp_cnt': 'int16',
 'ent_cardinal_pct': 'float32',
 'ent_cardinal_cnt': 'int16',
 'ent_date_pct': 'float32',
 'ent_date_cnt': 'int16',
 'ent_event_pct': 'float32',
 'ent_event_cnt': 'int16',
 'ent_fac_pct': 'float32',
 'ent_fac_cnt': 'int16',
 'ent_gpe_pct': 'float32',
 'ent_gpe_cnt': 'int16',
 'ent_language_pct': 'float32',
 'ent_language_cnt': 'int16',
 'ent_law_pct': 'float32',
 'ent_law_cnt': 'int16',
 'ent_loc_pct': 'float32',
 'ent_loc_cnt': 'int16',
 'ent_money_pct': 'float32',
 'ent_money_cnt': 'int16',
 'ent_norp_pct': 'float32',
 'ent_norp_cnt': 'int16',
 'ent_ordinal_pct': 'float32',
 'ent_ordinal_cnt': 'int16',
 'ent_org_pct': 'float32',
 'ent_org_cnt': 'int16',
 'ent_percent_pct': 'float32',
 'ent_percent_cnt': 'int16',
 'ent_person_pct': 'float32',
 'ent_person_cnt': 'int16',
 'ent_product_pct': 'float32',
 'ent_product_cnt': 'int16',
 'ent_quantity_pct': 'float32',
 'ent_quantity_cnt': 'int16',
 'ent_time_pct': 'float32',
 'ent_time_cnt': 'int16',
 'ent_work_of_art_pct': 'float32',
 'ent_work_of_art_cnt': 'int16'}

# %%
train = pd.read_csv(f"{filepath_prefix}train.csv", nrows=train_records_to_load,
                    true_values=["True"], false_values=["False"], dtype=datatypes)
test = pd.read_csv(f"{filepath_prefix}test.csv", nrows=test_records_to_load,
                   true_values=["True"], false_values=["False"], dtype=datatypes)

# %%
X_train = train.drop(columns=['review_id', 'target_clf', 'target_reg'])
X_test = test.drop(columns=['review_id', 'target_clf', 'target_reg'])
y_train = train['target_clf']
y_test = test['target_clf']

# %% [markdown]
# ## Basic Overview

# %%
train.head(5)
# Out:
#                 review_id  target_clf  target_reg  review_stars  nb_prob  \
# 0  syrAB11Ayj0qb64M3orNyQ       False           0             4  0.00000
# 1  ybCCcr1ICVynGJBx0lpBAw       False           0             4  0.88500
# 2  HBuNpb82_z25gLK2htZjZw        True           4             5  0.00400
# 3  RAIaaKEIg9gSJ-B4XcXBwA       False           0             1  0.00000
# 4  4fbqvddoQTLa7ChLJDYreg       False           0             5  0.00000
#
#    svm_pred  ft_prob  lda_t1  lda_t2  lda_t3  lda_t4  lda_t5  grade_level  \
# 0   0.80500  0.78156 0.00490 0.00489 0.83379 0.15149 0.00493     12.10000
# 1  -0.35600  0.61055 0.00686 0.00729 0.97217 0.00684 0.00685      5.30000
# 2  -0.01400  0.59267 0.00297 0.00297 0.21996 0.51115 0.26294     27.60000
# 3   0.89200  0.55841 0.57003 0.00150 0.00151 0.42545 0.00151      6.10000
# 4  -3.86300  0.25632 0.01018 0.01022 0.95915 0.01019 0.01026      4.60000
#
#    polarity  subjectivity  word_cnt  character_cnt  num_cnt  uppercase_cnt  \
# 0   0.13819       0.58714        91            552        0              3
# 1   0.44034       0.66364        57            338        0              0
# 2   0.28628       0.54253       151            764        0              6
# 3   0.02428       0.49481       327           1685        2              3
# 4   0.51250       0.67375        37            198        0              2
#
#    #@_cnt  sentence_cnt  lexicon_cnt  syllable_cnt  avg_word_len  token_cnt  \
# 0       0             3           95           123       4.71875        129
# 1       0             5           56            80       4.94737         66
# 2       0             2          143           188       4.06040        184
# 3       0            20          326           411       4.15596        373
# 4       0             4           37            50       4.37838         43
#
#    stopword_cnt  stopword_pct  ent_cnt  ent_pct  pos_adj_pct  pos_adj_cnt  \
# 0            51       0.39535        9  0.06977      0.10078           13
# 1            29       0.43939        2  0.03030      0.06061            4
# 2            80       0.43478        3  0.01630      0.08696           16
# 3           204       0.54692       16  0.04290      0.04021           15
# 4            17       0.39535        1  0.02326      0.13953            6
#
#    pos_adp_pct  pos_adp_cnt  pos_adv_pct  pos_adv_cnt  pos_aux_pct  \
# 0      0.06202            8      0.05426            7      0.05426
# 1      0.07576            5      0.09091            6      0.09091
# 2      0.08152           15      0.05978           11      0.05435
# 3      0.06971           26      0.06434           24      0.05362
# 4      0.04651            2      0.04651            2      0.02326
#
#    pos_aux_cnt  pos_conj_pct  pos_conj_cnt  pos_det_pct  pos_det_cnt  \
# 0            7       0.00000             0      0.09302           12
# 1            6       0.00000             0      0.10606            7
# 2           10       0.00000             0      0.13587           25
# 3           20       0.00000             0      0.13673           51
# 4            1       0.00000             0      0.16279            7
#
#    pos_intj_pct  pos_intj_cnt  pos_noun_pct  pos_noun_cnt  pos_num_pct  \
# 0       0.00775             1       0.09302            12      0.00000
# 1       0.00000             0       0.18182            12      0.00000
# 2       0.00000             0       0.17391            32      0.00000
# 3       0.01340             5       0.16622            62      0.03753
# 4       0.00000             0       0.18605             8      0.00000
#
#    pos_num_cnt  pos_part_pct  pos_part_cnt  pos_pron_pct  pos_pron_cnt  \
# 0            0       0.01550             2       0.07752            10
# 1            0       0.00000             0       0.03030             2
# 2            0       0.01630             3       0.06522            12
# 3           14       0.02949            11       0.07239            27
# 4            0       0.00000             0       0.04651             2
#
#    pos_propn_pct  pos_propn_cnt  pos_punct_pct  pos_punct_cnt  pos_sconj_pct  \
# 0        0.12403             16        0.16279             21        0.02326
# 1        0.06061              4        0.13636              9        0.03030
# 2        0.01630              3        0.14674             27        0.00543
# 3        0.01877              7        0.09920             37        0.01340
# 4        0.04651              2        0.13953              6        0.00000
#
#    pos_sconj_cnt  pos_sym_pct  pos_sym_cnt  pos_verb_pct  pos_verb_cnt  \
# 0              3      0.00000            0       0.06977             9
# 1              2      0.00000            0       0.12121             8
# 2              1      0.00543            1       0.07609            14
# 3              5      0.00000            0       0.12869            48
# 4              0      0.00000            0       0.09302             4
#
#    pos_x_pct  pos_x_cnt  dep_root_pct  dep_root_cnt  dep_acl_pct  dep_acl_cnt  \
# 0    0.00000          0       0.06977             9      0.00000            0
# 1    0.00000          0       0.09091             6      0.01515            1
# 2    0.00000          0       0.10326            19      0.00543            1
# 3    0.00000          0       0.06971            26      0.00000            0
# 4    0.00000          0       0.11628             5      0.00000            0
#
#    dep_acomp_pct  dep_acomp_cnt  dep_advcl_pct  dep_advcl_cnt  dep_advmod_pct  \
# 0        0.01550              2        0.00000              0         0.05426
# 1        0.03030              2        0.00000              0         0.09091
# 2        0.00543              1        0.00543              1         0.04891
# 3        0.01609              6        0.01609              6         0.05630
# 4        0.02326              1        0.00000              0         0.04651
#
#    dep_advmod_cnt  dep_agent_pct  dep_agent_cnt  dep_amod_pct  dep_amod_cnt  \
# 0               7        0.00000              0       0.07752            10
# 1               6        0.00000              0       0.04545             3
# 2               9        0.00000              0       0.08152            15
# 3              21        0.00000              0       0.03485            13
# 4               2        0.00000              0       0.06977             3
#
#    dep_appos_pct  dep_appos_cnt  dep_attr_pct  dep_attr_cnt  dep_aux_pct  \
# 0        0.01550              2       0.00775             1      0.02326
# 1        0.01515              1       0.00000             0      0.03030
# 2        0.00000              0       0.02174             4      0.02174
# 3        0.00536              2       0.00268             1      0.02949
# 4        0.02326              1       0.00000             0      0.00000
#
#    dep_aux_cnt  dep_auxpass_pct  dep_auxpass_cnt  dep_case_pct  dep_case_cnt  \
# 0            3          0.00000                0       0.01550             2
# 1            2          0.03030                2       0.00000             0
# 2            4          0.00000                0       0.00000             0
# 3           11          0.00536                2       0.00536             2
# 4            0          0.00000                0       0.00000             0
#
#    dep_cc_pct  dep_cc_cnt  dep_ccomp_pct  dep_ccomp_cnt  dep_compound_pct  \
# 0     0.02326           3        0.02326              3           0.06977
# 1     0.01515           1        0.03030              2           0.04545
# 2     0.03261           6        0.01630              3           0.03261
# 3     0.05898          22        0.01340              5           0.01072
# 4     0.06977           3        0.00000              0           0.02326
#
#    dep_compound_cnt  dep_conj_pct  dep_conj_cnt  dep_csubj_pct  dep_csubj_cnt  \
# 0                 9       0.04651             6        0.00000              0
# 1                 3       0.01515             1        0.00000              0
# 2                 6       0.01630             3        0.00000              0
# 3                 4       0.05630            21        0.00000              0
# 4                 1       0.06977             3        0.00000              0
#
#    dep_csubjpass_pct  dep_csubjpass_cnt  dep_dative_pct  dep_dative_cnt  \
# 0            0.00000                  0         0.00000               0
# 1            0.00000                  0         0.00000               0
# 2            0.00000                  0         0.00000               0
# 3            0.00000                  0         0.00000               0
# 4            0.00000                  0         0.00000               0
#
#    dep_dep_pct  dep_dep_cnt  dep_det_pct  dep_det_cnt  dep_dobj_pct  \
# 0      0.00000            0      0.04651            6       0.02326
# 1      0.00000            0      0.09091            6       0.03030
# 2      0.00000            0      0.08696           16       0.03261
# 3      0.00536            2      0.08311           31       0.06971
# 4      0.00000            0      0.11628            5       0.04651
#
#    dep_dobj_cnt  dep_expl_pct  dep_expl_cnt  dep_intj_pct  dep_intj_cnt  \
# 0             3       0.00000             0       0.00775             1
# 1             2       0.00000             0       0.00000             0
# 2             6       0.00543             1       0.00000             0
# 3            26       0.00000             0       0.00804             3
# 4             2       0.00000             0       0.00000             0
#
#    dep_mark_pct  dep_mark_cnt  dep_meta_pct  dep_meta_cnt  dep_neg_pct  \
# 0       0.00775             1       0.00000             0      0.00000
# 1       0.01515             1       0.00000             0      0.00000
# 2       0.00543             1       0.00000             0      0.01087
# 3       0.00804             3       0.00000             0      0.01609
# 4       0.00000             0       0.00000             0      0.00000
#
#    dep_neg_cnt  dep_nmod_pct  dep_nmod_cnt  dep_npadvmod_pct  \
# 0            0       0.00000             0           0.00000
# 1            0       0.00000             0           0.00000
# 2            2       0.00000             0           0.00000
# 3            6       0.00536             2           0.00000
# 4            0       0.00000             0           0.04651
#
#    dep_npadvmod_cnt  dep_nsubj_pct  dep_nsubj_cnt  dep_nsubjpass_pct  \
# 0                 0        0.06977              9            0.00000
# 1                 0        0.09091              6            0.03030
# 2                 0        0.08152             15            0.00000
# 3                 0        0.10992             41            0.00268
# 4                 2        0.09302              4            0.00000
#
#    dep_nsubjpass_cnt  dep_nummod_pct  dep_nummod_cnt  dep_oprd_pct  \
# 0                  0         0.00000               0       0.00000
# 1                  2         0.00000               0       0.00000
# 2                  0         0.00000               0       0.00000
# 3                  1         0.02145               8       0.00268
# 4                  0         0.00000               0       0.00000
#
#    dep_oprd_cnt  dep_parataxis_pct  dep_parataxis_cnt  dep_pcomp_pct  \
# 0             0            0.00775                  1        0.00000
# 1             0            0.00000                  0        0.00000
# 2             0            0.00543                  1        0.00000
# 3             1            0.00000                  0        0.00268
# 4             0            0.00000                  0        0.00000
#
#    dep_pcomp_cnt  dep_pobj_pct  dep_pobj_cnt  dep_poss_pct  dep_poss_cnt  \
# 0              0       0.06977             9       0.03101             4
# 1              0       0.06061             4       0.00000             0
# 2              0       0.07065            13       0.02174             4
# 3              1       0.05898            22       0.04021            15
# 4              0       0.02326             1       0.02326             1
#
#    dep_preconj_pct  dep_preconj_cnt  dep_predet_pct  dep_predet_cnt  \
# 0          0.00000                0         0.00000               0
# 1          0.00000                0         0.00000               0
# 2          0.00000                0         0.00000               0
# 3          0.00000                0         0.00000               0
# 4          0.00000                0         0.02326               1
#
#    dep_prep_pct  dep_prep_cnt  dep_prt_pct  dep_prt_cnt  dep_punct_pct  \
# 0       0.08527            11      0.00000            0        0.16279
# 1       0.06061             4      0.03030            2        0.12121
# 2       0.06522            12      0.00543            1        0.13587
# 3       0.06166            23      0.00268            1        0.09920
# 4       0.02326             1      0.02326            1        0.13953
#
#    dep_punct_cnt  dep_quantmod_pct  dep_quantmod_cnt  dep_relcl_pct  \
# 0             21           0.00000                 0        0.00775
# 1              8           0.00000                 0        0.01515
# 2             25           0.00543                 1        0.01087
# 3             37           0.01072                 4        0.00536
# 4              6           0.00000                 0        0.00000
#
#    dep_relcl_cnt  dep_xcomp_pct  dep_xcomp_cnt  ent_cardinal_pct  \
# 0              1        0.00000              0           0.00000
# 1              1        0.00000              0           0.00000
# 2              2        0.01087              2           0.00000
# 3              2        0.00536              2           0.03217
# 4              0        0.00000              0           0.00000
#
#    ent_cardinal_cnt  ent_date_pct  ent_date_cnt  ent_event_pct  ent_event_cnt  \
# 0                 0       0.00000             0        0.00000              0
# 1                 0       0.00000             0        0.00000              0
# 2                 0       0.00543             1        0.00000              0
# 3                12       0.00000             0        0.00000              0
# 4                 0       0.00000             0        0.00000              0
#
#    ent_fac_pct  ent_fac_cnt  ent_gpe_pct  ent_gpe_cnt  ent_language_pct  \
# 0      0.00000            0      0.00775            1           0.00000
# 1      0.00000            0      0.01515            1           0.00000
# 2      0.00000            0      0.00543            1           0.00000
# 3      0.00000            0      0.00000            0           0.00000
# 4      0.00000            0      0.00000            0           0.00000
#
#    ent_language_cnt  ent_law_pct  ent_law_cnt  ent_loc_pct  ent_loc_cnt  \
# 0                 0      0.00000            0      0.00000            0
# 1                 0      0.00000            0      0.00000            0
# 2                 0      0.00000            0      0.00543            1
# 3                 0      0.00000            0      0.00000            0
# 4                 0      0.00000            0      0.00000            0
#
#    ent_money_pct  ent_money_cnt  ent_norp_pct  ent_norp_cnt  ent_ordinal_pct  \
# 0        0.00000              0       0.02326             3          0.00000
# 1        0.00000              0       0.00000             0          0.00000
# 2        0.00000              0       0.00000             0          0.00000
# 3        0.00000              0       0.00268             1          0.00804
# 4        0.00000              0       0.00000             0          0.00000
#
#    ent_ordinal_cnt  ent_org_pct  ent_org_cnt  ent_percent_pct  \
# 0                0      0.00000            0          0.00000
# 1                0      0.00000            0          0.00000
# 2                0      0.00000            0          0.00000
# 3                3      0.00000            0          0.00000
# 4                0      0.00000            0          0.00000
#
#    ent_percent_cnt  ent_person_pct  ent_person_cnt  ent_product_pct  \
# 0                0         0.03876               5          0.00000
# 1                0         0.00000               0          0.00000
# 2                0         0.00000               0          0.00000
# 3                0         0.00000               0          0.00000
# 4                0         0.02326               1          0.00000
#
#    ent_product_cnt  ent_quantity_pct  ent_quantity_cnt  ent_time_pct  \
# 0                0           0.00000                 0       0.00000
# 1                0           0.00000                 0       0.00000
# 2                0           0.00000                 0       0.00000
# 3                0           0.00000                 0       0.00000
# 4                0           0.00000                 0       0.00000
#
#    ent_time_cnt  ent_work_of_art_pct  ent_work_of_art_cnt
# 0             0              0.00000                    0
# 1             0              0.01515                    1
# 2             0              0.00000                    0
# 3             0              0.00000                    0
# 4             0              0.00000                    0

# %%
train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 189 columns):
#  #    Column               Dtype
# ---   ------               -----
#  0    review_id            object
#  1    target_clf           bool
#  2    target_reg           int16
#  3    review_stars         int16
#  4    nb_prob              float64
#  5    svm_pred             float32
#  6    ft_prob              float32
#  7    lda_t1               float32
#  8    lda_t2               float32
#  9    lda_t3               float32
#  10   lda_t4               float32
#  11   lda_t5               float32
#  12   grade_level          float32
#  13   polarity             float32
#  14   subjectivity         float32
#  15   word_cnt             int16
#  16   character_cnt        int16
#  17   num_cnt              int16
#  18   uppercase_cnt        int16
#  19   #@_cnt               int16
#  20   sentence_cnt         int16
#  21   lexicon_cnt          int16
#  22   syllable_cnt         int16
#  23   avg_word_len         float32
#  24   token_cnt            int16
#  25   stopword_cnt         int16
#  26   stopword_pct         float32
#  27   ent_cnt              int16
#  28   ent_pct              float32
#  29   pos_adj_pct          float32
#  30   pos_adj_cnt          int16
#  31   pos_adp_pct          float32
#  32   pos_adp_cnt          int16
#  33   pos_adv_pct          float32
#  34   pos_adv_cnt          int16
#  35   pos_aux_pct          float32
#  36   pos_aux_cnt          int16
#  37   pos_conj_pct         float32
#  38   pos_conj_cnt         int16
#  39   pos_det_pct          float32
#  40   pos_det_cnt          int16
#  41   pos_intj_pct         float32
#  42   pos_intj_cnt         int16
#  43   pos_noun_pct         float32
#  44   pos_noun_cnt         int16
#  45   pos_num_pct          float32
#  46   pos_num_cnt          int16
#  47   pos_part_pct         float32
#  48   pos_part_cnt         int16
#  49   pos_pron_pct         float32
#  50   pos_pron_cnt         int16
#  51   pos_propn_pct        float32
#  52   pos_propn_cnt        int16
#  53   pos_punct_pct        float32
#  54   pos_punct_cnt        int16
#  55   pos_sconj_pct        float32
#  56   pos_sconj_cnt        int16
#  57   pos_sym_pct          float32
#  58   pos_sym_cnt          int16
#  59   pos_verb_pct         float32
#  60   pos_verb_cnt         int16
#  61   pos_x_pct            float32
#  62   pos_x_cnt            int16
#  63   dep_root_pct         float32
#  64   dep_root_cnt         int16
#  65   dep_acl_pct          float32
#  66   dep_acl_cnt          int16
#  67   dep_acomp_pct        float32
#  68   dep_acomp_cnt        int16
#  69   dep_advcl_pct        float32
#  70   dep_advcl_cnt        int16
#  71   dep_advmod_pct       float32
#  72   dep_advmod_cnt       int16
#  73   dep_agent_pct        float32
#  74   dep_agent_cnt        int16
#  75   dep_amod_pct         float32
#  76   dep_amod_cnt         int16
#  77   dep_appos_pct        float32
#  78   dep_appos_cnt        int16
#  79   dep_attr_pct         float32
#  80   dep_attr_cnt         int16
#  81   dep_aux_pct          float32
#  82   dep_aux_cnt          int16
#  83   dep_auxpass_pct      float32
#  84   dep_auxpass_cnt      int16
#  85   dep_case_pct         float32
#  86   dep_case_cnt         int16
#  87   dep_cc_pct           float32
#  88   dep_cc_cnt           int16
#  89   dep_ccomp_pct        float32
#  90   dep_ccomp_cnt        int16
#  91   dep_compound_pct     float32
#  92   dep_compound_cnt     int16
#  93   dep_conj_pct         float32
#  94   dep_conj_cnt         int16
#  95   dep_csubj_pct        float32
#  96   dep_csubj_cnt        int16
#  97   dep_csubjpass_pct    float32
#  98   dep_csubjpass_cnt    int16
#  99   dep_dative_pct       float32
#  100  dep_dative_cnt       int16
#  101  dep_dep_pct          float32
#  102  dep_dep_cnt          int16
#  103  dep_det_pct          float32
#  104  dep_det_cnt          int16
#  105  dep_dobj_pct         float32
#  106  dep_dobj_cnt         int16
#  107  dep_expl_pct         float32
#  108  dep_expl_cnt         int16
#  109  dep_intj_pct         float32
#  110  dep_intj_cnt         int16
#  111  dep_mark_pct         float32
#  112  dep_mark_cnt         int16
#  113  dep_meta_pct         float32
#  114  dep_meta_cnt         int16
#  115  dep_neg_pct          float32
#  116  dep_neg_cnt          int16
#  117  dep_nmod_pct         float32
#  118  dep_nmod_cnt         int16
#  119  dep_npadvmod_pct     float32
#  120  dep_npadvmod_cnt     int16
#  121  dep_nsubj_pct        float32
#  122  dep_nsubj_cnt        int16
#  123  dep_nsubjpass_pct    float32
#  124  dep_nsubjpass_cnt    int16
#  125  dep_nummod_pct       float32
#  126  dep_nummod_cnt       int16
#  127  dep_oprd_pct         float32
#  128  dep_oprd_cnt         int16
#  129  dep_parataxis_pct    float32
#  130  dep_parataxis_cnt    int16
#  131  dep_pcomp_pct        float32
#  132  dep_pcomp_cnt        int16
#  133  dep_pobj_pct         float32
#  134  dep_pobj_cnt         int16
#  135  dep_poss_pct         float32
#  136  dep_poss_cnt         int16
#  137  dep_preconj_pct      float32
#  138  dep_preconj_cnt      int16
#  139  dep_predet_pct       float32
#  140  dep_predet_cnt       int16
#  141  dep_prep_pct         float32
#  142  dep_prep_cnt         int16
#  143  dep_prt_pct          float32
#  144  dep_prt_cnt          int16
#  145  dep_punct_pct        float32
#  146  dep_punct_cnt        int16
#  147  dep_quantmod_pct     float32
#  148  dep_quantmod_cnt     int16
#  149  dep_relcl_pct        float32
#  150  dep_relcl_cnt        int16
#  151  dep_xcomp_pct        float32
#  152  dep_xcomp_cnt        int16
#  153  ent_cardinal_pct     float32
#  154  ent_cardinal_cnt     int16
#  155  ent_date_pct         float32
#  156  ent_date_cnt         int16
#  157  ent_event_pct        float32
#  158  ent_event_cnt        int16
#  159  ent_fac_pct          float32
#  160  ent_fac_cnt          int16
#  161  ent_gpe_pct          float32
#  162  ent_gpe_cnt          int16
#  163  ent_language_pct     float32
#  164  ent_language_cnt     int16
#  165  ent_law_pct          float32
#  166  ent_law_cnt          int16
#  167  ent_loc_pct          float32
#  168  ent_loc_cnt          int16
#  169  ent_money_pct        float32
#  170  ent_money_cnt        int16
#  171  ent_norp_pct         float32
#  172  ent_norp_cnt         int16
#  173  ent_ordinal_pct      float32
#  174  ent_ordinal_cnt      int16
#  175  ent_org_pct          float32
#  176  ent_org_cnt          int16
#  177  ent_percent_pct      float32
#  178  ent_percent_cnt      int16
#  179  ent_person_pct       float32
#  180  ent_person_cnt       int16
#  181  ent_product_pct      float32
#  182  ent_product_cnt      int16
#  183  ent_quantity_pct     float32
#  184  ent_quantity_cnt     int16
#  185  ent_time_pct         float32
#  186  ent_time_cnt         int16
#  187  ent_work_of_art_pct  float32
#  188  ent_work_of_art_cnt  int16
# dtypes: bool(1), float32(93), float64(1), int16(93), object(1)
# memory usage: 5.5+ MB

# %% [markdown]
# ## PyCaret AutoML Script - EC2

# %% [markdown]
# ### Optimizer Setup

# %%
# https://pycaret.readthedocs.io/en/latest/api/classification.html#module-pycaret.classification
pycaret_clf = setup(# Experiment Name
                    experiment_name="PyCaret_Clf_1M_2",
                    # Inbound Data
                    data=train.drop(columns=['review_id', 'target_reg']),
                    test_data=test.drop(columns=['review_id', 'target_reg']),
                    target='target_clf',
                    # Options
                    silent=True, preprocess=True, fold=5,
                    n_jobs=-1, log_experiment=True, session_id=7,
                    # Data Rescaling Options
                    normalize=True,
                    transformation=False,
                    # Data Trimming Options
                    remove_multicollinearity=False,
                    remove_outliers=False,
                    # PCA Dimensionality Reduction
                    pca=False, pca_components=10,
                    # Options to Add Features
                    create_clusters=False, 
                    polynomial_features=False,
                    trigonometry_features=False,
                    feature_interaction=False,
                    feature_ratio=False,
                    # Feature Reduction
                    feature_selection=False)
# Out:
# <style  type="text/css" >
# #T_9e407_row19_col1,#T_9e407_row29_col1,#T_9e407_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_9e407_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e407_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9e407_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_9e407_row0_col1" class="data row0 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9e407_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_9e407_row1_col1" class="data row1 col1" >target_clf</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9e407_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_9e407_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9e407_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_9e407_row3_col1" class="data row3 col1" >False: 0, True: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9e407_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_9e407_row4_col1" class="data row4 col1" >(10000, 187)</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9e407_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_9e407_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9e407_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_9e407_row6_col1" class="data row6 col1" >186</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9e407_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_9e407_row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_9e407_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_9e407_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_9e407_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_9e407_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_9e407_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_9e407_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_9e407_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_9e407_row11_col1" class="data row11 col1" >(10000, 182)</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_9e407_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_9e407_row12_col1" class="data row12 col1" >(10000, 182)</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_9e407_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_9e407_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_9e407_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_9e407_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_9e407_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_9e407_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_9e407_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_9e407_row16_col1" class="data row16 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_9e407_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_9e407_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_9e407_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_9e407_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_9e407_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_9e407_row19_col1" class="data row19 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_9e407_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_9e407_row20_col1" class="data row20 col1" >PyCaret_Clf_1M_2</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_9e407_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_9e407_row21_col1" class="data row21 col1" >4f6b</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_9e407_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_9e407_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_9e407_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_9e407_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_9e407_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_9e

# %% [markdown]
# ### Compare Models

# %%
top_models = compare_models(n_select = 3)
# Out:
# <style  type="text/css" >
#     #T_33434_ th {
#           text-align: left;
#     }#T_33434_row0_col0,#T_33434_row0_col2,#T_33434_row0_col3,#T_33434_row0_col4,#T_33434_row0_col5,#T_33434_row1_col0,#T_33434_row1_col1,#T_33434_row1_col2,#T_33434_row1_col3,#T_33434_row1_col5,#T_33434_row1_col6,#T_33434_row1_col7,#T_33434_row2_col0,#T_33434_row2_col1,#T_33434_row2_col2,#T_33434_row2_col3,#T_33434_row2_col4,#T_33434_row2_col5,#T_33434_row2_col6,#T_33434_row2_col7,#T_33434_row3_col0,#T_33434_row3_col1,#T_33434_row3_col3,#T_33434_row3_col4,#T_33434_row3_col6,#T_33434_row3_col7,#T_33434_row4_col0,#T_33434_row4_col1,#T_33434_row4_col2,#T_33434_row4_col3,#T_33434_row4_col4,#T_33434_row4_col5,#T_33434_row4_col6,#T_33434_row4_col7,#T_33434_row5_col0,#T_33434_row5_col1,#T_33434_row5_col2,#T_33434_row5_col3,#T_33434_row5_col4,#T_33434_row5_col5,#T_33434_row5_col6,#T_33434_row5_col7,#T_33434_row6_col0,#T_33434_row6_col1,#T_33434_row6_col2,#T_33434_row6_col3,#T_33434_row6_col4,#T_33434_row6_col5,#T_33434_row6_col6,#T_33434_row6_col7,#T_33434_row7_col0,#T_33434_row7_col1,#T_33434_row7_col2,#T_33434_row7_col4,#T_33434_row7_col5,#T_33434_row7_col6,#T_33434_row7_col7,#T_33434_row8_col0,#T_33434_row8_col1,#T_33434_row8_col2,#T_33434_row8_col3,#T_33434_row8_col4,#T_33434_row8_col5,#T_33434_row8_col6,#T_33434_row8_col7,#T_33434_row9_col0,#T_33434_row9_col1,#T_33434_row9_col2,#T_33434_row9_col3,#T_33434_row9_col4,#T_33434_row9_col5,#T_33434_row9_col6,#T_33434_row9_col7,#T_33434_row10_col0,#T_33434_row10_col1,#T_33434_row10_col2,#T_33434_row10_col3,#T_33434_row10_col4,#T_33434_row10_col5,#T_33434_row10_col6,#T_33434_row10_col7,#T_33434_row11_col0,#T_33434_row11_col1,#T_33434_row11_col2,#T_33434_row11_col3,#T_33434_row11_col4,#T_33434_row11_col5,#T_33434_row11_col6,#T_33434_row11_col7,#T_33434_row12_col0,#T_33434_row12_col1,#T_33434_row12_col2,#T_33434_row12_col3,#T_33434_row12_col4,#T_33434_row12_col5,#T_33434_row12_col6,#T_33434_row12_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_33434_row0_col1,#T_33434_row0_col6,#T_33434_row0_col7,#T_33434_row1_col4,#T_33434_row3_col2,#T_33434_row3_col5,#T_33434_row7_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_33434_row0_col8,#T_33434_row1_col8,#T_33434_row2_col8,#T_33434_row3_col8,#T_33434_row4_col8,#T_33434_row5_col8,#T_33434_row6_col8,#T_33434_row7_col8,#T_33434_row8_col8,#T_33434_row10_col8,#T_33434_row11_col8,#T_33434_row12_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_33434_row9_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_33434_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_33434_level0_row0" class="row_heading level0 row0" >ridge</th>
#                         <td id="T_33434_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#                         <td id="T_33434_row0_col1" class="data row0 col1" >0.6713</td>
#                         <td id="T_33434_row0_col2" class="data row0 col2" >0.0000</td>
#                         <td id="T_33434_row0_col3" class="data row0 col3" >0.6320</td>
#                         <td id="T_33434_row0_col4" class="data row0 col4" >0.6868</td>
#                         <td id="T_33434_row0_col5" class="data row0 col5" >0.6581</td>
#                         <td id="T_33434_row0_col6" class="data row0 col6" >0.3427</td>
#                         <td id="T_33434_row0_col7" class="data row0 col7" >0.3439</td>
#                         <td id="T_33434_row0_col8" class="data row0 col8" >0.0540</td>
#             </tr>
#             <tr>
#                         <th id="T_33434_level0_row1" class="row_heading level0 row1" >lr</th>
#                         <td id="T_33434_row1_col0" class="data row1 col0" >Logistic Regression</td>
#                         <td id="T_33434_row1_col1" class="data row1 col1" >0.6710</td>
#                         <td id="T_33434_row1_col2" class="data row1 col2" >0.7338</td>
#                         <td id="T_33434_row1_col3" class="data row1 col3" >0.6246</td>
#                         <td id="T_33434_row1_col4" class="data row1 col4" >0.6894</td>
#                         <td id="T_33434_row1_col5" class="data row1 col5" >0.6552</td>
#                         <td id="T_33434_row1_col6" class="data row1 col6" >0.3421</td>
#                         <td id="T_33434_row1_col7" class="data row1 col7" >0.3438</td>
#                         <td id="T_33434_row1_col8" class="data row1 col8" >1.6700</td>
#             </tr>
#             <tr>
#                         <th id="T_33434_level0_row2" class="row_heading level0 row2" >lda</th>
#                         <td id="T_33434_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#                         <td id="T_33434_row2_col1" class="data row2 col1" >0.6708</td>
#                         <td id="T_33434_row2_col2" class="data row2 col2" >0.7303</td>
#                         <td id="T_33434_row2_col3" class="data row2 col3" >0.6318</td>
#                         <td id="T_33434_row2_col4" class="data row2 col4" >0.6862</td>
#                         <td id="T_33434_row2_col5" class="data row2 col5" >0.6577</td>
#                         <td id="T_33434_row2_col6" class="data row2 col6" >0.3417</td>
#                         <td id="T_33434_row2_col7" class="data row2 col7" >0.3429</td>
#                         <td id="T_33434_row2_col8" class="data row2 col8" >0.1820</td>
#             </tr>
#             <tr>
#                         <th id="T_33434_level0_row3" class="row_heading level0 row3" >gbc</th>
#                         <td id="T_33434_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_33434_row3_col1" class="data row3 col1" >0.6706</td>
#                         <td id="T_33434_row3_col2" class="data row3 col2" >0.7353</td>
#                         <td id="T_33434_row3_col3" class="data row3 col3" >0.6386</td>
#                         <td id="T_33434_row3_col4" class="data row3 col4" >0.6833</td>
#                         <td id="T_33434_row3_col5" class="data row3 col5" >0.6599</td>
#                         <td id="T_33434_row3_col6" class="data row3 col6" >0.3413</td>
#                         <td id="T_33434_row3_col7" class="data row3 col7" >0.3423</td>
#                         <td id="T_33434_row3_col8" class="data row3 col8" >4.8940</td>
#             </tr>
#             <tr>
#                         <th id="T_33434_level0_row4" class="row_heading level0 row4" >ada</th>
#                         <td id="T_33434_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#                         <td id="T_33434_row4_col1" class="data row4 col1" >0.6669</td>
#                         <td id="T_33434_row4_col2" class="data row4 col2" >0.7263</td>
#                         <td id="T_33434_row4_col3" class="data row4 col3" >0.6152</td>
#                         <td id="T_33434_row4_col4" class="data row4 col4" >0.6870</td>
#                         <td id="T_33434_row4_col5" class="data row4 col5" >0.6488</td>
#                         <td id="T_33434_row4_col6" class="data row4 col6" >0.3339</td>
#                         <td id="T_33434_row4_col7" class="data row4 col7" >0.3360</td>
#                         <td id="T_33434_row4_col8" class="data row4 col8

# %% [markdown]
# ### Specific Model Creation and Tuning

# %%
log_reg = create_model('lr', fold = 10)
# Out:
# <style  type="text/css" >
# #T_dceb8_row10_col0,#T_dceb8_row10_col1,#T_dceb8_row10_col2,#T_dceb8_row10_col3,#T_dceb8_row10_col4,#T_dceb8_row10_col5,#T_dceb8_row10_col6{
#             background:  yellow;
#         }</style><table id="T_dceb8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dceb8_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dceb8_row0_col0" class="data row0 col0" >0.6610</td>
#                         <td id="T_dceb8_row0_col1" class="data row0 col1" >0.7076</td>
#                         <td id="T_dceb8_row0_col2" class="data row0 col2" >0.6300</td>
#                         <td id="T_dceb8_row0_col3" class="data row0 col3" >0.6716</td>
#                         <td id="T_dceb8_row0_col4" class="data row0 col4" >0.6502</td>
#                         <td id="T_dceb8_row0_col5" class="data row0 col5" >0.3220</td>
#                         <td id="T_dceb8_row0_col6" class="data row0 col6" >0.3226</td>
#             </tr>
#             <tr>
#                         <th id="T_dceb8_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dceb8_row1_col0" class="data row1 col0" >0.6750</td>
#                         <td id="T_dceb8_row1_col1" class="data row1 col1" >0.7523</td>
#                         <td id="T_dceb8_row1_col2" class="data row1 col2" >0.6200</td>
#                         <td id="T_dceb8_row1_col3" class="data row1 col3" >0.6966</td>
#                         <td id="T_dceb8_row1_col4" class="data row1 col4" >0.6561</td>
#                         <td id="T_dceb8_row1_col5" class="data row1 col5" >0.3500</td>
#                         <td id="T_dceb8_row1_col6" class="data row1 col6" >0.3521</td>
#             </tr>
#             <tr>
#                         <th id="T_dceb8_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dceb8_row2_col0" class="data row2 col0" >0.6550</td>
#                         <td id="T_dceb8_row2_col1" class="data row2 col1" >0.7228</td>
#                         <td id="T_dceb8_row2_col2" class="data row2 col2" >0.6028</td>
#                         <td id="T_dceb8_row2_col3" class="data row2 col3" >0.6741</td>
#                         <td id="T_dceb8_row2_col4" class="data row2 col4" >0.6365</td>
#                         <td id="T_dceb8_row2_col5" class="data row2 col5" >0.3101</td>
#                         <td id="T_dceb8_row2_col6" class="data row2 col6" >0.3119</td>
#             </tr>
#             <tr>
#                         <th id="T_dceb8_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dceb8_row3_col0" class="data row3 col0" >0.6640</td>
#                         <td id="T_dceb8_row3_col1" class="data row3 col1" >0.7193</td>
#                         <td id="T_dceb8_row3_col2" class="data row3 col2" >0.6148</td>
#                         <td id="T_dceb8_row3_col3" class="data row3 col3" >0.6829</td>
#                         <td id="T_dceb8_row3_col4" class="data row3 col4" >0.6471</td>
#                         <td id="T_dceb8_row3_col5" class="data row3 col5" >0.3281</td>
#                         <td id="T_dceb8_row3_col6" class="data row3 col6" >0.3298</td>
#             </tr>
#             <tr>
#                         <th id="T_dceb8_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dceb8_row4_col0" class="data row4 col0" >0.6700</td>
#                         <td id="T_dceb8_row4_col1" class="data row4 col1" >0.7358</td>
#                         <td id="T_dceb8_row4_col2" class="data row4 col2" >0.6228</td>
#                         <td id="T_dceb8_row4_col3" class="data row4 col3" >0.6887</td>
#                         <td id="T_dceb8_row4_col4" class="data row4 col4" >0.6541</td>
#                         <td id="T_dceb8_row4_col5" class="data row4 col5" >0.3401</td>
#                         <td id="T_dceb8_row4_col6" class="data row4 col6" >0.3417</td>
#             </tr>
#             <tr>
#                         <th id="T_dceb8_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dceb8_row5_col0" class="data row5 col0" >0.6640</td>
#                         <td id="T_dceb8_row5_col1" class="data row5 col1" >0.7221</td>
#                         <td id="T_dceb8_row5_col2" class="data row5 col2" >0.5868</td>
#                         <td id="T_dceb8_row5_col3" class="data row5 col3" >0.6950</td>
#                         <td id="T_dceb8_row5_col4" class="data row5 col4" >0.6364</td>
#                         <td id="T_dceb8_row5_col5" class="data row5 col5" >0.3282</td>
#                         <td id="T_dceb8_row5_col6" class="data row5 col6" >0.3323</td>
#             </tr>
#             <tr>
#                         <th id="T_dceb8_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dceb8_row6_col0" class="data row6 col0" >0.6550</td>
#                         <td id="T_dceb8_row6_col1" class="data row6 col1" >0.7274</td>
#                         <td id="T_dceb8_row6_col2" class="data row6 col2" >0.6048</td>
#                         <td id="T_dceb8_row6_col3" class="data row6 col3" >0.6733</td>
#                         <td id="T_dceb8_row6_col4" class="data row6 col4" >0.6372</td>
#                         <td id="T_dceb8_row6_col5" class="data row6 col5" >0.3101</td>
#                         <td id="T_dceb8_row6_col6" class="data row6 col6" >0.3118</td>
#             </tr>
#             <tr>
#                         <th id="T_dceb8_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dceb8_row7_col0" class="data row7 col0" >0.7100</td>
#                         <td id="T_dceb8_row7_col1" class="data row7 col1" >0.7690</td>
#                         <td id="T_dceb8_row7_col2" class="data row7 col2" >0.6327</td>
#                         <td id="T_dceb8_row7_col3" class="data row7 col3" >0.7494</td>
#                         <td id="T_dceb8_row7_col4" class="data row7 col4" >0.6861</td>
#                         <td id="T_dceb8_row7_col5" class="data row7 col5" >0.4202</td>
#                         <td id="T_dceb8_row7_col6" class="data row7 col6" >0.4254</td>
#             </tr>
#             <tr>
#                         <th id="T_dceb8_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_dceb8_row8_col0" class="data row8 col0" >0.6780</td>
#                         <td id="T_dceb8_row8_col1" class="data row8 col1" >0.7535</td>
#                         <td id="T_dceb8_row8_col2" class="data row8 col2" >0.6687</td>
#                         <td id="T_dceb8_row8_col3" class="data row8 col3" >0.6823</td>
#                         <td id="T_dceb8_row8_col4" class="data row8 col4" >0.6754</td>
#                         <td id="T_dceb8_row8_col5" class="data row8 col5" >0.3560</td>
#                         <td id="T_dceb8_row8_col6" class="data row8 col6" >0.3561</td>
#             </tr>
#             <tr>
#                         <th id="T_dceb8_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_dceb8_row9_col0" class="data row9 col0" >0.6730</td>
#                         <td id="T_dceb8_row9_col1" class="data row9 col1" >0.7486</td>
#                         <td id="T_dceb8_row9_col2" class="data row9 col2" >0.6407</td>
#                         <td id="T_dceb8_row9_col3" class="data row9 col3" >0.6859</td>
#                         <td id="T_dceb8_row9_col4" class="data row9 col4" >0.6625</td>
#                         <td id="T_dceb8_row9_col5" class="data row9 col5" >0.3461</td>
#                         <td id=

# %%
tuned_log_reg = tune_model(log_reg, optimize = 'Accuracy')
# Out:
# <style  type="text/css" >
# #T_87b6d_row5_col0,#T_87b6d_row5_col1,#T_87b6d_row5_col2,#T_87b6d_row5_col3,#T_87b6d_row5_col4,#T_87b6d_row5_col5,#T_87b6d_row5_col6{
#             background:  yellow;
#         }</style><table id="T_87b6d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_87b6d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_87b6d_row0_col0" class="data row0 col0" >0.6715</td>
#                         <td id="T_87b6d_row0_col1" class="data row0 col1" >0.7293</td>
#                         <td id="T_87b6d_row0_col2" class="data row0 col2" >0.6274</td>
#                         <td id="T_87b6d_row0_col3" class="data row0 col3" >0.6886</td>
#                         <td id="T_87b6d_row0_col4" class="data row0 col4" >0.6566</td>
#                         <td id="T_87b6d_row0_col5" class="data row0 col5" >0.3431</td>
#                         <td id="T_87b6d_row0_col6" class="data row0 col6" >0.3444</td>
#             </tr>
#             <tr>
#                         <th id="T_87b6d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_87b6d_row1_col0" class="data row1 col0" >0.6605</td>
#                         <td id="T_87b6d_row1_col1" class="data row1 col1" >0.7186</td>
#                         <td id="T_87b6d_row1_col2" class="data row1 col2" >0.6034</td>
#                         <td id="T_87b6d_row1_col3" class="data row1 col3" >0.6817</td>
#                         <td id="T_87b6d_row1_col4" class="data row1 col4" >0.6402</td>
#                         <td id="T_87b6d_row1_col5" class="data row1 col5" >0.3211</td>
#                         <td id="T_87b6d_row1_col6" class="data row1 col6" >0.3232</td>
#             </tr>
#             <tr>
#                         <th id="T_87b6d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_87b6d_row2_col0" class="data row2 col0" >0.6735</td>
#                         <td id="T_87b6d_row2_col1" class="data row2 col1" >0.7276</td>
#                         <td id="T_87b6d_row2_col2" class="data row2 col2" >0.6128</td>
#                         <td id="T_87b6d_row2_col3" class="data row2 col3" >0.6985</td>
#                         <td id="T_87b6d_row2_col4" class="data row2 col4" >0.6528</td>
#                         <td id="T_87b6d_row2_col5" class="data row2 col5" >0.3472</td>
#                         <td id="T_87b6d_row2_col6" class="data row2 col6" >0.3498</td>
#             </tr>
#             <tr>
#                         <th id="T_87b6d_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_87b6d_row3_col0" class="data row3 col0" >0.6780</td>
#                         <td id="T_87b6d_row3_col1" class="data row3 col1" >0.7426</td>
#                         <td id="T_87b6d_row3_col2" class="data row3 col2" >0.6148</td>
#                         <td id="T_87b6d_row3_col3" class="data row3 col3" >0.7048</td>
#                         <td id="T_87b6d_row3_col4" class="data row3 col4" >0.6567</td>
#                         <td id="T_87b6d_row3_col5" class="data row3 col5" >0.3562</td>
#                         <td id="T_87b6d_row3_col6" class="data row3 col6" >0.3591</td>
#             </tr>
#             <tr>
#                         <th id="T_87b6d_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_87b6d_row4_col0" class="data row4 col0" >0.6805</td>
#                         <td id="T_87b6d_row4_col1" class="data row4 col1" >0.7503</td>
#                         <td id="T_87b6d_row4_col2" class="data row4 col2" >0.6627</td>
#                         <td id="T_87b6d_row4_col3" class="data row4 col3" >0.6881</td>
#                         <td id="T_87b6d_row4_col4" class="data row4 col4" >0.6751</td>
#                         <td id="T_87b6d_row4_col5" class="data row4 col5" >0.3610</td>
#                         <td id="T_87b6d_row4_col6" class="data row4 col6" >0.3613</td>
#             </tr>
#             <tr>
#                         <th id="T_87b6d_level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_87b6d_row5_col0" class="data row5 col0" >0.6728</td>
#                         <td id="T_87b6d_row5_col1" class="data row5 col1" >0.7337</td>
#                         <td id="T_87b6d_row5_col2" class="data row5 col2" >0.6242</td>
#                         <td id="T_87b6d_row5_col3" class="data row5 col3" >0.6923</td>
#                         <td id="T_87b6d_row5_col4" class="data row5 col4" >0.6563</td>
#                         <td id="T_87b6d_row5_col5" class="data row5 col5" >0.3457</td>
#                         <td id="T_87b6d_row5_col6" class="data row5 col6" >0.3476</td>
#             </tr>
#             <tr>
#                         <th id="T_87b6d_level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_87b6d_row6_col0" class="data row6 col0" >0.0069</td>
#                         <td id="T_87b6d_row6_col1" class="data row6 col1" >0.0113</td>
#                         <td id="T_87b6d_row6_col2" class="data row6 col2" >0.0207</td>
#                         <td id="T_87b6d_row6_col3" class="data row6 col3" >0.0082</td>
#                         <td id="T_87b6d_row6_col4" class="data row6 col4" >0.0112</td>
#                         <td id="T_87b6d_row6_col5" class="data row6 col5" >0.0139</td>
#                         <td id="T_87b6d_row6_col6" class="data row6 col6" >0.0136</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Evaluate Model/Plotting

# %%
evaluate_model(tuned_log_reg)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
interpret_model(tuned_log_reg)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pycaret/internal/tabular.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    7462         try:
# -> 7463             import shap
#    7464         except ImportError:
#
# ModuleNotFoundError: No module named 'shap'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-c4b5f2ccbd18> in <module>
# ----> 1 interpret_model(tuned_log_reg)
#
# ~/anaconda3/lib/python3.8/site-packages/pycaret/classification.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1711     """
#    1712
# -> 1713     return pycaret.internal.tabular.interpret_model(
#    1714         estimator=estimator,
#    1715         plot=plot,
#
# ~/anaconda3/lib/python3.8/site-packages/pycaret/internal/tabular.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    7466                 "shap library not found. pip install shap to use interpret_model function."
#    7467             )
# -> 7468             raise ImportError(
#    7469                 "shap library not found. pip install shap to use interpret_model function."
#    7470             )
#
# ImportError: shap library not found. pip install shap to use interpret_model function.

# %% [markdown]
# ### Predict on Test Data

# %%
predict_model(tuned_log_reg);
# Out:
# <style  type="text/css" >
# </style><table id="T_7d52d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7d52d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7d52d_row0_col0" class="data row0 col0" >Logistic Regression</td>
#                         <td id="T_7d52d_row0_col1" class="data row0 col1" >0.6418</td>
#                         <td id="T_7d52d_row0_col2" class="data row0 col2" >0.6951</td>
#                         <td id="T_7d52d_row0_col3" class="data row0 col3" >0.5917</td>
#                         <td id="T_7d52d_row0_col4" class="data row0 col4" >0.6567</td>
#                         <td id="T_7d52d_row0_col5" class="data row0 col5" >0.6226</td>
#                         <td id="T_7d52d_row0_col6" class="data row0 col6" >0.2835</td>
#                         <td id="T_7d52d_row0_col7" class="data row0 col7" >0.2849</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Finalize and Save Model

# %%
# save_model(tuned_log_reg, 'pycaret_log_reg')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[],
#                                        target='target_clf', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_...
#                                         target_variable='target_clf',
#                                         threshold=0.9)),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   LogisticRegression(C=0.46, class_weight={}, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=7,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False)]],
#           verbose=False),
#  'pycaret_1M_log_reg.pkl')

# %%
# save_model(tuned_gbm, 'pycaret_light_gbm')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[],
#                                        target='target_clf', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_...
#                                  boosting_type='gbdt', class_weight=None,
#                                  colsample_bytree=1.0, feature_fraction=0.9,
#                                  importance_type='split', learning_rate=0.2,
#                                  max_depth=-1, min_child_samples=66,
#                                  min_child_weight=0.001, min_split_gain=0.1,
#                                  n_estimators=100, n_jobs=-1, num_leaves=30,
#                                  objective=None, random_state=7, reg_alpha=0.001,
#                                  reg_lambda=0.4, silent=True, subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0)]],
#           verbose=False),
#  'pycaret_1M_light_gbm.pkl')
